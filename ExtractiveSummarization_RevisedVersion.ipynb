# %% [markdown]
# ## Training the BERTSUM model
# The code for training a BERTSUM model is open-sourced by the researchers of BERTSUM and it is available at https://github.com/nlpyang/BertSum. In this section, let us explore this and learn how to train the BERTSUM model. We will train the BERTSUM model on the CNN/DailyMail news dataset.
#
# ** Makse sure to run the notebook in GPU
# First, let us install the necessary libraries **
#
# ## 1. Installation

# %%
# !pip install pytorch_pretrained_bert
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install pytorch_transformers==1.2.0
# !pip install tensorboardX==1.9
#!pip install multiprocess==0.70.9
# !pip install pyrouge
# !pip install googleDriveFileDownloader
# Out:
# Collecting pytorch_pretrained_bert
#   Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl.metadata (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (2.10.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (2.0.2)
# Collecting boto3 (from pytorch_pretrained_bert)
#   Downloading boto3-1.43.6-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from pytorch_pretrained_bert) (2025.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=0.4.1->pytorch_pretrained_bert) (1.5.3)
# Collecting botocore<1.44.0,>=1.43.6 (from boto3->pytorch_pretrained_bert)
#   Downloading botocore-1.43.6-py3-none-any.whl.metadata (5.5 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->pytorch_pretrained_bert)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.18.0,>=0.17.0 (from boto3->pytorch_pretrained_bert)
#   Downloading s3transfer-0.17.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_pretrained_bert) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_pretrained_bert) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_pretrained_bert) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_pretrained_bert) (2026.4.22)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.44.0,>=1.43.6->boto3->pytorch_pretrained_bert) (2.9.0.post0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.1->pytorch_pretrained_bert) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.1->pytorch_pretrained_bert) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.6->boto3->pytorch_pretrained_bert) (1.17.0)
# Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 9.5 MB/s eta 0:00:00
# Downloading boto3-1.43.6-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 19.9 MB/s eta 0:00:00
# Downloading botocore-1.43.6-py3-none-any.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 84.3 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.17.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3, pytorch_pretrained_bert
# Successfully installed boto3-1.43.6 botocore-1.43.6 jmespath-1.1.0 pytorch_pretrained_bert-0.6.2 s3transfer-0.17.0
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ERROR: Could not find a version that satisfies the requirement torch==1.11.0+cu113 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0)
# ERROR: No matching distribution found for torch==1.11.0+cu113
# Collecting pytorch_transformers==1.2.0
#   Downloading pytorch_transformers-1.2.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_transformers==1.2.0) (2.10.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pytorch_transformers==1.2.0) (2.0.2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.12/dist-packages (from pytorch_transformers==1.2.0) (1.43.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pytorch_transformers==1.2.0) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pytorch_transformers==1.2.0) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from pytorch_transformers==1.2.0) (2025.11.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from pytorch_transformers==1.2.0) (0.2.1)
# Collecting sacremoses (from pytorch_transformers==1.2.0)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->pytorch_transformers==1.2.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.0.0->pytorch_transformers==1.2.0) (1.5.3)
# Requirement already satisfied: botocore<1.44.0,>=1.43.6 in /usr/local/lib/python3.12/dist-packages (from boto3->pytorch_transformers==1.2.0) (1.43.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3->pytorch_transformers==1.2.0) (1.1.0)
# Requirement already satisfied: s3transfer<0.18.0,>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from boto3->pytorch_transformers==1.2.0) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_transformers==1.2.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_transformers==1.2.0) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_transformers==1.2.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pytorch_transformers==1.2.0) (2026.4.22)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from sacremoses->pytorch_transformers==1.2.0) (8.3.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from sacremoses->pytorch_transformers==1.2.0) (1.5.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.44.0,>=1.43.6->boto3->pytorch_transformers==1.2.0) (2.9.0.post0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->pytorch_transformers==1.2.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->pytorch_transformers==1.2.0) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.6->boto3->pytorch_transformers==1.2.0) (1.17.0)
# Downloading pytorch_transformers-1.2.0-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 8.6 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 41.7 MB/s eta 0:00:00
# Installing collected packages: sacremoses, pytorch_transformers
# Successfully installed pytorch_transformers-1.2.0 sacremoses-0.1.1
# Collecting tensorboardX==1.9
#   Downloading tensorboardX-1.9-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tensorboardX==1.9) (2.0.2)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from tensorboardX==1.9) (5.29.6)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from tensorboardX==1.9) (1.17.0)
# Downloading tensorboardX-1.9-py2.py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.7/190.7 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-1.9
# Collecting pyrouge
#   Downloading pyrouge-0.1.3.tar.gz (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyrouge
#   Building wheel for pyrouge (setup.py) ... done
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-py3-none-any.whl size=191604 sha256=0e86e49d11e5d27719378be149af9d6dba931624214f2692745443c3caf66512
#   Stored in directory: /root/.cache/pip/wheels/dc/cd/82/f15f0faa70543a7e697d68f29f14e626ce7a44a9644a2f619c
# Successfully built pyrouge
# Installing collected packages: pyrouge
# Successfully installed pyrouge-0.1.3
# Collecting googleDriveFileDownloader
#   Downloading googleDriveFileDownloader-1.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from googleDriveFileDownloader) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->googleDriveFileDownloader) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->googleDriveFileDownloader) (4.15.0)
# Downloading googleDriveFileDownloader-1.2-py3-none-any.whl (15 kB)
# Installing collected packages: googleDriveFileDownloader
# Successfully installed googleDriveFileDownloader-1.2

# %% [markdown]
# #### ** An Issue with Pyrouge (1/3) **
#
# This [colab](https://colab.research.google.com/drive/1-vAnr3d3W8GtqSCn4MwjrdQrzN0uCXzx?usp=sharing#scrollTo=nJrExsDcIJiB) project has resolved the [problem](https://github.com/nlpyang/BertSum/issues/35) with Pyrouge. Essentially, it involves cloning the two Pyrouge repositories into separate folders and then directing to the Pyrouge-1.5.5 within the tools folder.

# %%
# !pip install pyrouge --upgrade
# !pip install https://github.com/bheinzerling/pyrouge/archive/master.zip
# !pip install pyrouge
# !pip show pyrouge
# !git clone https://github.com/andersjo/pyrouge.git
from pyrouge import Rouge155
# !pyrouge_set_rouge_path '/content/pyrouge/tools/ROUGE-1.5.5'
# Out:
# Requirement already satisfied: pyrouge in /usr/local/lib/python3.12/dist-packages (0.1.3)
# Collecting https://github.com/bheinzerling/pyrouge/archive/master.zip
#   Downloading https://github.com/bheinzerling/pyrouge/archive/master.zip
#      | 202.3 kB 794.3 kB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyrouge in /usr/local/lib/python3.12/dist-packages (0.1.3)
# Name: pyrouge
# Version: 0.1.3
# Summary: A Python wrapper for the ROUGE summarization evaluation package.
# Home-page: https://github.com/noutenki/pyrouge
# Author: Benjamin Heinzerling, Anders Johannsen
# Author-email: benjamin.heinzerling@h-its.org
# License: LICENSE.txt
# Location: /usr/local/lib/python3.12/dist-packages
# Requires:
# Required-by:
# Cloning into 'pyrouge'...
# remote: Enumerating objects: 393, done.
# remote: Total 393 (delta 0), reused 0 (delta 0), pack-reused 393 (from 1)
# Receiving objects: 100% (393/393), 298.74 KiB | 1.58 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# 2026-05-11 13:29:42,904 [MainThread  ] [INFO ]  Set ROUGE home directory to /content/pyrouge/tools/ROUGE-1.5.5.

# %% [markdown]
# #### ** An Issue with Pyrouge (2/3) **
#
# A new issue has arisen with ROUGE-1.5.5 related to the XML Parser. A potential solution can be found at the following links:
#
# * [https://blog.csdn.net/qq_33220757/article/details/105692883](https://blog.csdn.net/qq_33220757/article/details/105692883)
#
# * [http://kavita-ganesan.com/rouge-howto/#.X0fJey1ePOQ](http://kavita-ganesan.com/rouge-howto/#.X0fJey1ePOQ)

# %%
# !sudo apt-get install libxml-parser-perl
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libauthen-sasl-perl libclone-perl libdata-dump-perl libencode-locale-perl
#   libfile-listing-perl libfont-afm-perl libhtml-form-perl libhtml-format-perl
#   libhtml-parser-perl libhtml-tagset-perl libhtml-tree-perl
#   libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libio-html-perl
#   libio-socket-ssl-perl liblwp-mediatypes-perl liblwp-protocol-https-perl
#   libmailtools-perl libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libtry-tiny-perl liburi-perl libwww-perl libwww-robotrules-perl netbase
#   perl-openssl-defaults
# Suggested packages:
#   libdigest-hmac-perl libgssapi-perl libcrypt-ssleay-perl libsub-name-perl
#   libbusiness-isbn-perl libauthen-ntlm-perl
# The following NEW packages will be installed:
#   libauthen-sasl-perl libclone-perl libdata-dump-perl libencode-locale-perl
#   libfile-listing-perl libfont-afm-perl libhtml-form-perl libhtml-format-perl
#   libhtml-parser-perl libhtml-tagset-perl libhtml-tree-perl
#   libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libio-html-perl
#   libio-socket-ssl-perl liblwp-mediatypes-perl liblwp-protocol-https-perl
#   libmailtools-perl libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libtry-tiny-perl liburi-perl libwww-perl libwww-robotrules-perl
#   libxml-parser-perl netbase perl-openssl-defaults
# 0 upgraded, 31 newly installed, 0 to remove and 100 not upgraded.
# Need to get 1,782 kB of archives.
# After this operation, 5,559 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 netbase all 6.3 [12.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclone-perl amd64 0.45-1build3 [11.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdata-dump-perl all 1.25-1 [25.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libencode-locale-perl all 1.05-1.1 [11.8 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-date-perl all 6.05-1 [9,920 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfile-listing-perl all 6.14-1 [11.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfont-afm-perl all 1.20-3 [13.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-tagset-perl all 3.20-4 [12.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 liburi-perl all 5.10-1 [78.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-parser-perl amd64 3.76-1build2 [88.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-html-perl all 1.004-2 [15.4 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblwp-mediatypes-perl all 6.04-1 [19.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-message-perl all 6.36-1 [76.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-form-perl all 6.07-1 [22.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-tree-perl all 5.07-2 [200 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-format-perl all 2.12-1.1 [41.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-cookies-perl all 6.10-1 [18.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libhttp-daemon-perl all 6.13-1ubuntu0.1 [22.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-negotiate-perl all 6.01-1 [12.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 perl-openssl-defaults amd64 5build2 [7,542 B]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnet-ssleay-perl amd64 1.92-1build2 [327 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-socket-ssl-perl all 2.074-2 [192 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnet-http-perl all 6.22-1 [23.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtry-tiny-perl all 0.31-1 [21.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwww-robotrules-perl all 6.02-1 [12.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwww-perl all 6.61-1 [141 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblwp-protocol-https-perl all 6.10-1 [10.9 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnet-smtp-ssl-perl all 1.04-1 [5,948 B]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmailtools-perl all 2.21-1 [80.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxml-parser-perl amd64 2.46-3ubuntu0.1 [212 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libauthen-sasl-perl all 2.1600-1.1 [43.1 kB]
# Fetched 1,782 kB in 0s (4,058 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 31.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package netbase.
# (Reading database ... 122402 files and directories currently installed.)
# Preparing to unpack .../00-netbase_6.3_all.deb ...
# Unpacking netbase (6.3) ...
# Selecting previously unselected package libclone-perl.
# Preparing to unpack .../01-libclone-perl_0.45-1build3_amd64.deb ...
# Unpacking libclone-perl (0.45-1build3) ...
# Selecting previously unselected package libdata-dump-perl.
# Preparing to unpack .../02-libdata-dump-perl_1.25-1_all.deb ...
# Unpacking libdata-dump-perl (1.25-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../03-libencode-locale-perl_1.05-1.1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1.1) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../04-libhttp-date-perl_6.05-1_all.deb ...
# Unpacking libhttp-date-perl (6.05-1) ...
# Selecting previously unselected package libfile-listing-perl.
# Preparing to unpack .../05-libfile-listing-perl_6.14-1_all.deb ...
# Unpacking libfile-listing-perl (6.14-1) ...
# Selecting previously unselected package libfont-afm-perl.
# Preparing to unpack .../06-libfont-afm-perl_1.20-3_all.deb ...
# Unpacking libfont-afm-perl (1.20-3) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../07-libhtml-tagset-perl_3.20-4_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-4) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../08-liburi-perl_5.10-1_all.deb ...
# Unpacking liburi-perl (5.10-1) ...
# Selecting previously unselected package libhtml-parser-perl:amd64.
# Preparing to unpack .../09-libhtml-parser-perl_3.76-1build2_amd64.deb ...
# Unpacking libhtml-parser-perl:amd64 (3.76-1build2) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../10-libio-html-perl_1.004-2_all.deb ...
# Unpacking libio-html-perl (1.004-2) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../11-liblwp-mediatypes-perl_6.04-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.04-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../12-libhttp-message-perl_6.36-1_all.deb ...
# Unpacking libhttp-message-perl (6.36-1) ...
# Selecting previously unselected package libhtml-form-perl.
# Preparing to unpack .../13-libhtml-form-perl_6.07-1_all.deb ...
# Unpacking libhtml-form-perl (6.07-1) ...
# Selecting previously unselected package libhtml-tree-perl.
# Preparing to unpack .../14-libhtml-tree-perl_5.07-2_all.deb ...
# Unpacking libhtml-tree-perl (5.07-2) ...
# Selecting previously unselected package libhtml-format-perl.
# Preparing to unpack .../15-libhtml-format-perl_2.12-1.1_all.deb ...
# Unpacking libhtml-format-perl (2.12-1.1) ...
# Selecting previously unselected package libhttp-cookies-perl.
# Preparing to unpack .../16-libhttp-cookies-perl_6.10-1_all.deb ...
# Unpacking libhttp-cookies-perl (6.10-1) ...
# Selecting previously unselected package libhttp-daemon-perl.
# Preparing to unpack .../17-libhttp-daemon-perl_6.13-1ubuntu0.1_all.deb ...
# Unpacking libhttp-daemon-perl (6.13-1ubuntu0.1) ...
# Selecting previously unselected package libhttp-negotiate-perl.
# Preparing to unpack .../18-libhttp-negotiate-perl_6.01-1_all.deb ...
# Unpacking libhttp-negotiate-perl (6.01-1) ...
# Selecting previously unselected package perl-openssl-defaults:amd64.
# Preparing to unpack .../19-perl-openssl-defaults_5build2_amd64.deb ...
# Unpacking perl-openssl-defaults:amd64 (5build2) ...
# Selecting previously unselected package libnet-ssleay-perl:amd64.
# Preparing to unpack .../20-libnet-ssleay-perl_1.92-1build2_amd64.deb ...
# Unpacking libnet-ssleay-perl:amd64 (1.92-1build2) ...
# Selecting previously unselected package libio-socket-ssl-perl.
# Preparing to unpack .../21-libio-socket-ssl-perl_2.074-2_all.deb ...
# Unpacking libio-socket-ssl-perl (2.074-2) ...
# Selecting previously unselected package libnet-http-perl.
# Preparing to unpack .../22-libnet-http-perl_6.22-1_all.deb ...
# Unpacking libnet-http-perl (6.22-1) ...
# Selecting previously unselected package libtry-tiny-perl.
# Preparing to unpack .../23-libtry-tiny-perl_0.31-1_all.deb ...
# Unpacking libtry-tiny-perl (0.31-1) ...
# Selecting previously unselected package libwww-robotrules-perl.
# Preparing to unpack .../24-libwww-robotrules-perl_6.02-1_all.deb ...
# Unpacking libwww-robotrules-perl (6.02-1) ...
# Selecting previously unselected package libwww-perl.
# Preparing to unpack .../25-libwww-perl_6.61-1_all.deb ...
# Unpacking libwww-perl (6.61-1) ...
# Selecting previously unselected package liblwp-protocol-https-perl.
# Preparing to unpack .../26-liblwp-protocol-https-perl_6.10-1_all.deb ...
# Unpacking liblwp-protocol-https-perl (6.10-1) ...
# Selecting previously unselected package libnet-smtp-ssl-perl.
# Preparing to unpack .../27-libnet-smtp-ssl-perl_1.04-1_all.deb ...
# Unpacking libnet-smtp-ssl-perl (1.04-1) ...
# Selecting previously unselected package libmailtools-perl.
# Preparing to unpack .../28-libmailtools-perl_2.21-1_all.deb ...
# Unpacking libmailtools-perl (2.21-1) ...
# Selecting previously unselected package libxml-parser-perl:amd64.
# Preparing to unpack .../29-libxml-parser-perl_2.46-3ubuntu0.1_amd64.deb ...
# Unpacking libxml-parser-perl:amd64 (2.46-3ubuntu0.1) ...
# Selecting previously unselected package libauthen-sasl-perl.
# Preparing to unpack .../30-libauthen-sasl-perl_2.1600-1.1_all.deb ...
# Unpacking libauthen-sasl-perl (2.1600-1.1) ...
# Setting up libhttp-date-perl (6.05-1) ...
# Setting up libfile-listing-perl (6.14-1) ...
# Setting up libfont-afm-perl (1.20-3) ...
# Setting up libclone-perl (0.45-1build3) ...
# Setting up libhtml-tagset-perl (3.20-4) ...
# Setting up libauthen-sasl-perl (2.1600-1.1) ...
# Setting up liblwp-mediatypes-perl (6.04-1) ...
# Setting up libtry-tiny-perl (0.31-1) ...
# Setting up perl-openssl-defaults:amd64 (5build2) ...
# Setting up libencode-locale-perl (1.05-1.1) ...
# Setting up libdata-dump-perl (1.25-1) ...
# Setting up libio-html-perl (1.004-2) ...
# Setting up netbase (6.3) ...
# Setting up liburi-perl (5.10-1) ...
# Setting up libhttp-message-perl (6.36-1) ...
# Setting up libnet-ssleay-perl:amd64 (1.92-1build2) ...
# Setting up libhttp-negotiate-perl (6.01-1) ...
# Setting up libhttp-cookies-perl (6.10-1) ...
# Setting up libnet-http-perl (6.22-1) ...
# Setting up libwww-robotrules-perl (6.02-1) ...
# Setting up libhttp-daemon-perl (6.13-1ubuntu0.1) ...
# Setting up libhtml-parser-perl:amd64 (3.76-1build2) ...
# Setting up libio-socket-ssl-perl (2.074-2) ...
# Setting up libhtml-form-perl (6.07-1) ...
# Setting up libhtml-tree-perl (5.07-2) ...
# Setting up libhtml-format-perl (2.12-1.1) ...
# Setting up libnet-smtp-ssl-perl (1.04-1) ...
# Setting up libmailtools-perl (2.21-1) ...
# Setting up liblwp-protocol-https-perl (6.10-1) ...
# Setting up libwww-perl (6.61-1) ...
# Setting up libxml-parser-perl:amd64 (2.46-3ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# #### ** An Issue with Pyrouge (3/3) **
#
# A new issue has been identified with WordNet-2.0.exc.db. The solution can be found at [https://github.com/tagucci/pythonrouge](https://github.com/tagucci/pythonrouge)

# %%
# %%shell
# cd pyrouge/tools/ROUGE-1.5.5/data
# rm WordNet-2.0.exc.db # only if exist
# cd WordNet-2.0-Exceptions
# rm WordNet-2.0.exc.db # only if exist
#
# ./buildExeptionDB.pl . exc WordNet-2.0.exc.db
# cd ../
# ln -s WordNet-2.0-Exceptions/WordNet-2.0.exc.db WordNet-2.0.exc.db
# Out:
# Streaming output truncated to the last 5000 lines.
# hyraces
# iambi
# ibices
# ibo
# ichthyosauri
# ichthyosauruses
# iconostases
# icosahedra
# ideata
# igorrorote
# ilia
# imagines
# imagoes
# imperia
# impies
# incubi
# incudes
# indices
# indigoes
# indumenta
# indusia
# infundibula
# ingushes
# innuendoes
# inocula
# inquisitors-general
# insectaria
# insulae
# intagli
# interleaves
# intermezzi
# interreges
# interregna
# intimae
# involucella
# involucra
# involucra
# irides
# irs
# is
# ischia
# isthmi
# jackeroos
# jackfishes
# jackknives
# jacks-in-the-box
# jambeaux
# jellyfishes
# jewelfishes
# jewfishes
# jingoes
# jinn
# joes
# judge_advocates_general
# jura
# kaddishim
# kalmuck
# kalmucks
# katabases
# keeshonden
# kibbutzim
# killifishes
# kingfishes
# kings-of-arms
# knights_bachelor
# knights_bachelors
# knights_templar
# knights_templars
# knives
# kohlrabies
# kronen
# kroner
# kronur
# krooni
# kylikes
# labara
# labella
# labia
# labra
# lactobacilli
# lacunae
# lacunaria
# ladies-in-waiting
# lamellae
# lamiae
# laminae
# lapilli
# lapithae
# larvae
# larynges
# lassoes
# lati
# latices
# latifundia
# latu
# lavaboes
# leaves
# lecythi
# leges
# lei
# lemmata
# lemnisci
# lenes
# lentigines
# leonides
# lepidoptera
# leprosaria
# lepta
# leptocephali
# leucocytozoa
# leva
# librae
# libretti
# lice
# lieder
# ligulae
# limbi
# limina
# limites
# limuli
# lingoes
# linguae
# linguae_francae
# lionfishes
# lipomata
# lire
# liriodendra
# listente
# litai
# litu
# lives
# lixivia
# loaves
# loci
# loculi
# loggie
# logia
# lomenta
# longobardi
# loricae
# luba
# lubritoria
# lumbus
# lumina
# lumpfishes
# lungfishes
# lunulae
# lures
# lustra
# lyings-in
# lymphangitides
# lymphomata
# lymphopoieses
# lyses
# lyttae
# maare
# macaronies
# maccaronies
# machzorim
# macronuclei
# macrosporangia
# maculae
# madornos
# maestri
# mafiosi
# magi
# magmata
# magnificoes
# mahzorim
# major-axes
# major_axes
# makuta
# mallei
# malleoli
# maloti
# mamillae
# mammae
# mammillae
# mandingoes
# mangoes
# manifestoes
# manteaux
# mantes
# manubria
# marchese
# marchesi
# maremme
# markkaa
# marsupia
# marvels-of-peru
# mass_media
# masses
# masters-at-arms
# matrices
# matzoth
# mausolea
# maxillae
# maxima
# media
# mediae
# mediastina
# medullae
# medullae_oblongatae
# medusae
# megara
# megasporangia
# megilloth
# meioses
# melanomata
# melismata
# mementoes
# memoranda
# men
# men-at-arms
# men-o'-war
# men-of-war
# men_of_letters
# menisci
# menservants
# menstrua
# mesdames
# mesdemoiselles
# mesentera
# mesothoraces
# messeigneurs
# messieurs
# mestizoes
# metacarpi
# metamorphoses
# metanephroi
# metastases
# metatarsi
# metatheses
# metathoraces
# metazoa
# metempsychoses
# metencephala
# mezuzoth
# miasmata
# mice
# microanalyses
# micrococci
# micronuclei
# microsporangia
# midrashim
# midwives
# milia
# milieux
# militated_against
# milkfishes
# millennia
# minae
# minima
# ministeria
# minutiae
# minyanim
# mioses
# miracidia
# miri
# mishnayoth
# mitochondria
# mitzvoth
# modioli
# moduli
# momenta
# moments_of_truth
# momi
# monades
# monkfishes
# monochasia
# monopodia
# monoptera
# monopteroi
# monsignori
# monts-de-piete
# mooncalves
# moonfishes
# morae
# moratoria
# morceaux
# morescoes
# moriscoes
# morphallaxes
# morphoses
# morulae
# mosasauri
# moshavim
# moslim
# moslims
# mosquitoes
# mothers-in-law
# mothers_superior
# mottoes
# movers_and_shakers
# mucosae
# mucrones
# mudejares
# mudfishes
# mulattoes
# multiparae
# murices
# muskallunge
# mycelia
# mycetomata
# mycobacteria
# mycorrhizae
# myelencephala
# myiases
# myocardia
# myofibrillae
# myomata
# myoses
# myrmidones
# mythoi
# myxomata
# naevi
# naiades
# naoi
# narcissi
# nares
# nasopharynges
# natatoria
# naumachiae
# nauplii
# nautili
# navahoes
# navajoes
# nebulae
# necropoleis
# needlefishes
# negrilloes
# negritoes
# negroes
# nemeses
# nephridia
# nereides
# neurohypophyses
# neuromata
# neuroptera
# neuroses
# nevi
# nibelungen
# nidi
# nielli
# nilgai
# nimbi
# nimbostrati
# noctilucae
# nodi
# noes
# nomina
# nota
# noumena
# novae
# novelle
# novenae
# nubeculae
# nucelli
# nuchae
# nuclei
# nucleoli
# nulliparae
# numbfishes
# numina
# nymphae
# oarfishes
# oases
# obeli
# objets_d'art
# obligati
# oboli
# occipita
# oceanaria
# oceanides
# ocelli
# ochreae
# ocreae
# octahedra
# octopi
# oculi
# odea
# oedemata
# oesophagi
# oldwives
# olea
# omasa
# omayyades
# omenta
# ommatidia
# ommiades
# onagri
# oogonia
# oothecae
# operas_seria
# opercula
# optima
# ora
# organa
# organums
# orthoptera
# osar
# oscula
# ossa
# osteomata
# ostia
# ottomans
# ova
# ovoli
# ovotestes
# oxen
# oxymora
# paddlefishes
# paise
# paleae
# palestrae
# palingeneses
# pallia
# palmettoes
# palpi
# pancratia
# panettoni
# paparazzi
# paperknives
# papillae
# papillomata
# pappi
# papulae
# papyri
# parabases
# paraleipses
# paralyses
# paramecia
# paramenta
# paraphyses
# parapodia
# parapraxes
# paraselenae
# parashoth
# parasyntheta
# parazoa
# parentheses
# parerga
# parhelia
# parietes
# paris-mutuels
# parrotfishes
# parulides
# pasos_dobles
# passers-by
# pastorali
# patagia
# patellae
# patinae
# patresfamilias
# pease
# peccadilloes
# pectines
# pedaloes
# pedes
# pekingese
# pelves
# pence
# penes
# penetralium
# penicillia
# penknives
# pennae
# pennia
# pentahedra
# pentimenti
# penumbrae
# pepla
# pericardia
# perichondria
# pericrania
# peridia
# perigonia
# perihelia
# perinea
# perinephria
# perionychia
# periostea
# periphrases
# peristalses
# perithecia
# peritonea
# personae
# petechiae
# pfennige
# phalanges
# phalli
# pharynges
# phenomena
# phi-phenomena
# philodendra
# phlyctenae
# phyla
# phylae
# phyllotaxes
# phylloxerae
# phylogeneses
# pieds-a-terre
# pigfishes
# pilea
# pilei
# pineta
# pinfishes
# pinkoes
# pinnae
# pinnulae
# pipefishes
# pirogi
# piscinae
# pithecanthropi
# pithoi
# placeboes
# placentae
# planetaria
# planulae
# plasmodesmata
# plasmodia
# plateaux
# plectra
# plena
# pleura
# pleurae
# plicae
# ploughmen
# pneumobacilli
# pneumococci
# pocketknives
# podetia
# podia
# poleis
# pollices
# pollinia
# polychasia
# polyhedra
# polyparia
# polypi
# polyzoa
# polyzoaria
# pontes
# pontifices
# portamenti
# porticoes
# portmanteaux
# postliminia
# potatoes
# praenomina
# praxes
# predelle
# premaxillae
# prenomina
# prese
# primi
# primigravidae
# primiparae
# primordia
# principia
# proboscides
# proces-verbaux
# proglottides
# prognoses
# prolegomena
# prolepses
# promycelia
# pronephra
# pronephroi
# pronuclei
# propositi
# proptoses
# propyla
# propylaea
# proscenia
# prosencephala
# prostheses
# prostomia
# protases
# prothalamia
# prothalli
# prothallia
# prothoraces
# protonemata
# protozoa
# proventriculi
# provisoes
# prytanea
# psalteria
# pseudopodia
# psychoneuroses
# psychoses
# pterygia
# pterylae
# ptoses
# pubes
# pudenda
# puli
# pulvilli
# pulvini
# punchinelloes
# pupae
# puparia
# putamina
# putti
# pycnidia
# pygidia
# pylori
# pyxides
# pyxidia
# qaddishim
# quadrennia
# quadrigae
# qualia
# quanta
# quarterstaves
# quezales
# quinquennia
# quizzes
# rabatos
# rabbitfishes
# rachides
# radices
# radii
# radulae
# ramenta
# rami
# ranulae
# ranunculi
# raphae
# raphides
# ratfishes
# reales
# rearmice
# recta
# recti
# rectrices
# redfishes
# rediae
# referenda
# refugia
# reguli
# reis
# relata
# remiges
# reremice
# reseaux
# residua
# responsa
# retia
# retiarii
# reticula
# retinacula
# retinae
# rhabdomyomata
# rhachides
# rhachises
# rhinencephala
# rhizobia
# rhombi
# rhonchi
# rhyta
# ribbonfishes
# ricercacari
# ricercari
# rickettsiae
# rilievi
# rimae
# robes-de-chambre
# rockfishes
# roma
# romans-fleuves
# rondeaux
# rosaria
# rosefishes
# rostella
# rostra
# rouleaux
# rugae
# rumina
# runners-up
# sacra
# sacraria
# saguaros
# sailfishes
# salespeople
# salmonellae
# salpae
# salpinges
# saltarelli
# salvoes
# sancta
# sanitaria
# santimi
# saphenae
# sarcophagi
# sartorii
# sassanidae
# sawfishes
# scaldfishes
# scaleni
# scapulae
# scarabaei
# scarves
# schatchonim
# schemata
# scherzandi
# scherzi
# schmoes
# scholia
# schuln
# schutzstaffeln
# scirrhi
# scleromata
# scleroses
# sclerotia
# scoleces
# scolices
# scopulae
# scoriae
# scotomata
# scriptoria
# scrota
# scudi
# scuta
# scutella
# scyphi
# scyphistomae
# scyphozoa
# secondi
# secretaries-general
# segni
# seleucidae
# selves
# senores
# sensilla
# senti
# senussis
# separatrices
# sephardim
# septa
# septaria
# septennia
# sequelae
# sequestra
# sera
# seraphim
# sestertia
# setae
# sgraffiti
# shabbasim
# shabbatim
# shackoes
# shadchanim
# shadchans
# shakoes
# shammosim
# sheatfishes
# sheaves
# shellfishes
# shelves
# shinleaves
# shittim
# shmoes
# shofroth
# shophroth
# shrewmice
# shuln
# siddurim
# sigloi
# signore
# signori
# signorine
# siliquae
# silvae
# silverfishes
# simulacra
# sincipita
# sinfonie
# sisters-in-law
# sistra
# situlae
# smalti
# snaggleteeth
# snailfishes
# snipefishes
# socmen
# sola
# solaria
# solatia
# soldi
# soles
# solfeggi
# soli
# solidi
# somata
# sons-in-law
# soprani
# sordini
# sori
# soroses
# sovkhozy
# spadefishes
# spadices
# spearfishes
# spectra
# specula
# spermatia
# spermatogonia
# spermatozoa
# spermogonia
# sphinges
# spicae
# spicula
# spirilla
# splayfeet
# splenii
# sporangia
# sporogonia
# sporozoa
# springhase
# spumoni
# sputa
# squamae
# squashes
# squillae
# squirrelfishes
# squizzes
# stadia
# stamina
# staminodia
# stapedes
# staphylococci
# starfishes
# startsy
# stelae
# stemmata
# stenoses
# stepchildren
# sterna
# stigmata
# stimuli
# stipites
# stirpes
# stoae
# stockfishes
# stomata
# stomodaea
# stomodea
# stonefishes
# stotinki
# stotkini
# strappadoes
# strata
# strati
# stratocumuli
# street_children
# streptococci
# stretti
# striae
# strobili
# stromata
# strumae
# stuccoes
# styli
# stylopes
# stylopodia
# subcortices
# subdeliria
# subgenera
# subindices
# submucosae
# subphyla
# substrasta
# succedanea
# succubi
# suckerfishes
# suckfishes
# sudaria
# sudatoria
# sulci
# summae
# sunfishes
# supercargoes
# superheroes
# supernovae
# superstrata
# surgeonfishes
# swamies
# sweetiewives
# swellfishes
# swordfishes
# syconia
# syllabi
# syllepses
# symphyses
# sympodia
# symposia
# synapses
# synarthroses
# synclinoria
# syncytia
# syndesmoses
# synopses
# syntagmata
# syntheses
# syphilomata
# syringes
# syssarcoses
# tableaux
# taeniae
# tali
# tallaisim
# tallithes
# tallitoth
# tapeta
# tarantulae
# tarsi
# tarsometatarsi
# taxa
# taxes
# taxies
# tectrices
# teeth
# tegmina
# telae
# telamones
# telangiectases
# telia
# tempi
# tenacula
# tenderfeet
# teniae
# tenues
# teraphim
# terata
# teredines
# terga
# termini
# terraria
# terzetti
# tesserae
# testae
# testes
# testudines
# tetrahedra
# tetraskelia
# thalamencephala
# thalami
# thalli
# theatres-in-the-round
# thecae
# therses
# thesauri
# theses
# thickleaves
# thieves
# tholoi
# thoraces
# thrombi
# thymi
# thyrsi
# tibiae
# tilefishes
# tintinnabula
# titmice
# toadfishes
# tobaccoes
# tomatoes
# tomenta
# tondi
# tonneaux
# tophi
# topoi
# tori
# tornadoes
# torpedoes
# torsi
# touracos
# trabeculae
# tracheae
# traditores
# tragi
# trapezia
# trapezohedra
# traumata
# treponemata
# trichinae
# triclinia
# triennia
# triforia
# triggerfishes
# trihedra
# triskelia
# trisoctahedra
# triumviri
# trivia
# trochleae
# tropaeola
# trous-de-loup
# trousseaux
# trunkfishes
# trymata
# tubae
# turves
# tympana
# tyros
# ubermenschen
# uglies
# uigurs
# ulnae
# ultimata
# umbilici
# umbones
# umbrae
# unci
# uncidia
# uredines
# uredinia
# uredosori
# urethrae
# urinalyses
# uteri
# utriculi
# uvulae
# vacua
# vagi
# vaginae
# valleculae
# vaporetti
# varices
# vasa
# vascula
# vela
# velamina
# velaria
# venae
# venae_cavae
# ventriculi
# vermes
# verrucae
# vertebrae
# vertices
# vertigines
# vertigoes
# vesicae
# vetoes
# vexilla
# viatica
# viatores
# vibracula
# vibrissae
# vice-chairman
# villi
# vimina
# vincula
# viragoes
# vires
# virtuosi
# vitae
# vitelli
# vittae
# vivaria
# voces
# volcanoes
# volkslieder
# volte
# volvae
# vorticellae
# vortices
# vulvae
# wagons-lits
# wahhabis
# wanderjahre
# weakfishes
# werewolves
# wharves
# whippers-in
# whitefishes
# wives
# wolffishes
# wolves
# woodlice
# wreckfishes
# wunderkinder
# xiphisterna
# yeshivahs
# yeshivoth
# yogin
# yourselves
# zamindaris
# zecchini
# zeroes
# zoa
# zoaeae
# zoeae
# zoeas
# zoonoses
# zoosporangia
# verb.exc
# abetted
# abetting
# abhorred
# abhorring
# abode
# abought
# about-shipped
# about-shipping
# abutted
# abutting
# abye
# accompanied
# acetified
# acidified
# acquitted
# acquitting
# ad-libbed
# ad-libbing
# addrest
# admitted
# admitting
# aerified
# air-dried
# airdropped
# airdropping
# alkalified
# allied
# allotted
# allotting
# allowed_for
# allowing_for
# allows_for
# am
# ammonified
# amnestied
# amplified
# anglified
# annulled
# annulling
# appalled
# appalling
# applied
# arcked
# arcking
# are
# argufied
# arisen
# arose
# ate
# atrophied
# averred
# averring
# awoke
# awoken
# babied
# baby-sat
# baby-sitting
# back-pedalled
# back-pedalling
# backbit
# backbitten
# backslid
# backslidden
# bade
# bagged
# bagging
# ballyragged
# ballyragging
# bandied
# banned
# banning
# barred
# barrelled
# barrelling
# barring
# basified
# batted
# batting
# bayonetted
# bayonetting
# beaten
# beatified
# beautified
# became
# became_known
# becomes_known
# bed
# bedded
# bedding
# bedevilled
# bedevilling
# bedimmed
# bedimming
# been
# befallen
# befell
# befitted
# befitting
# befogged
# befogging
# began
# begat
# begetting
# begged
# begging
# beginning
# begirt
# begot
# begotten
# begun
# beheld
# beholden
# bejewelled
# bejewelling
# bellied
# belly-flopped
# belly-flopping
# belying
# benefitted
# benefitting
# benempt
# bent
# berried
# besetting
# besought
# bespoke
# bespoken
# bestirred
# bestirring
# bestrewn
# bestrid
# bestridden
# bestrode
# betaken
# bethought
# betook
# betted
# betting
# bevelled
# bevelling
# biassed
# biassing
# bidden
# bidding
# bing
# binned
# binning
# bird-dogged
# bird-dogging
# bit
# bitted
# bitten
# bitting
# bivouacked
# bivouacking
# blabbed
# blabbing
# blackberried
# blacklegged
# blacklegging
# blatted
# blatting
# bled
# blest
# blew
# blew_one's_nose
# blipped
# blipping
# blobbed
# blobbing
# bloodied
# blotted
# blotting
# blowing_one's_nose
# blown
# blows_one's_nose
# blubbed
# blubbing
# blue-pencilled
# blue-pencilling
# blurred
# blurring
# bobbed
# bobbing
# bodied
# bogged-down
# bogged_down
# bogging-down
# bogging_down
# bogs-down
# bogs_down
# booby-trapped
# booby-trapping
# bootlegged
# bootlegging
# bopped
# bopping
# bore
# born
# borne
# bottle-fed
# bought
# bound
# bragged
# bragging
# breast-fed
# bred
# brevetted
# brevetting
# brimmed
# brimming
# broke
# broken
# brought
# browbeaten
# brutified
# budded
# budding
# bugged
# bugging
# built
# bulldogging
# bullied
# bullshitted
# bullshitting
# bullwhipped
# bullwhipping
# bullyragged
# bullyragging
# bummed
# bumming
# buried
# burnt
# burred
# burring
# bushelled
# bushelling
# busied
# bypast
# caballed
# caballing
# caddied
# caddies
# caddying
# calcified
# came
# canalled
# canalling
# cancelled
# cancelling
# candied
# canned
# canning
# canopied
# capped
# capping
# carburetted
# carburetting
# carillonned
# carillonning
# carnied
# carnified
# carolled
# carolling
# carried
# casefied
# catnapped
# catnapping
# catted
# catting
# caught
# cavilled
# cavilling
# certified
# channelled
# channelling
# chapped
# chapping
# charred
# charring
# chatted
# chatting
# chevied
# chevies
# chevying
# chid
# chidden
# chinned
# chinning
# chipped
# chipping
# chiselled
# chiselling
# chitchatted
# chitchatting
# chivied
# chivved
# chivvied
# chivvies
# chivving
# chivvying
# chondrified
# chopped
# chopping
# chose
# chosen
# chugged
# chugging
# chummed
# chumming
# citified
# clad
# cladding
# clammed
# clamming
# clapped
# clapping
# clarified
# classified
# cleft
# clemmed
# clemming
# clept
# clipped
# clipping
# clogged
# clogging
# clopped
# clopping
# clotted
# clotting
# clove
# cloven
# clubbed
# clubbing
# clung
# co-opted
# co-opting
# co-opts
# co-ordinate
# co-ordinated
# co-ordinates
# co-ordinating
# co-starred
# co-starring
# cockneyfied
# codded
# codding
# codified
# cogged
# cogging
# coiffed
# coiffing
# collied
# combatted
# combatting
# committed
# committing
# compelled
# compelling
# complied
# complotted
# complotting
# concurred
# concurring
# confabbed
# confabbing
# conferred
# conferring
# conned
# conning
# controlled
# controlling
# copied
# copped
# copping
# coquetted
# coquetting
# corralled
# corralling
# counselled
# counselling
# counterplotted
# counterplotting
# countersank
# countersunk
# court-martialled
# court-martialling
# crabbed
# crabbing
# crammed
# cramming
# crapped
# crapping
# crept
# cribbed
# cribbing
# cried
# cropped
# cropping
# crossbred
# crosscutting
# crucified
# cubbed
# cubbing
# cudgelled
# cudgelling
# cupelled
# cupelling
# cupped
# cupping
# curetted
# curettes
# curetting
# curried
# curst
# curtsied
# curvetted
# curvetting
# cutting
# dabbed
# dabbing
# dagged
# dagging
# dallied
# dammed
# damming
# damnified
# dandified
# dapped
# dapping
# dealt
# debarred
# debarring
# debugged
# debugging
# debussed
# debusses
# debussing
# decalcified
# declassified
# decontrolled
# decontrolling
# decried
# deep-freeze
# deep-freezed
# deep-freezes
# deep-fried
# deferred
# deferring
# defied
# degassed
# degasses
# degassing
# dehumidified
# deified
# demitted
# demitting
# demobbed
# demobbing
# demulsified
# demurred
# demurring
# demystified
# denazified
# denied
# denitrified
# denned
# denning
# descried
# deterred
# deterring
# detoxified
# devilled
# devilling
# devitrified
# diagrammed
# diagramming
# dialled
# dialling
# dibbed
# dibbing
# did
# digging
# dignified
# dilly-dallied
# dimmed
# dimming
# dinned
# dinning
# dipped
# dipping
# dirtied
# disannulled
# disannulling
# disbarred
# disbarring
# disbudded
# disbudding
# disembodied
# disembowelled
# disembowelling
# disenthralled
# disenthralling
# disenthralls
# disenthrals
# dishevelled
# dishevelling
# disinterred
# disinterring
# dispelled
# dispelling
# disqualified
# dissatisfied
# distilled
# distilling
# diversified
# divvied
# dizzied
# dogged
# dogging
# doglegged
# doglegging
# dollied
# done
# donned
# donning
# dotted
# dotting
# dought
# dove
# drabbed
# drabbing
# dragged
# dragging
# drank
# drawn
# dreamt
# drew
# dried
# dripped
# dripping
# drivelled
# drivelling
# driven
# dropped
# dropping
# drove
# drubbed
# drubbing
# drugged
# drugging
# drummed
# drumming
# drunk
# dubbed
# dubbing
# duelled
# duelling
# dug
# dulcified
# dummied
# dunned
# dunning
# dwelt
# dying
# easied
# eaten
# eavesdropped
# eavesdropping
# eddied
# edified
# ego-tripped
# ego-tripping
# electrified
# embedded
# embedding
# embodied
# embussed
# embusses
# embussing
# emitted
# emitting
# empanelled
# empanelling
# emptied
# emulsified
# enamelled
# enamelling
# englutted
# englutting
# enrolled
# enrolling
# enthralled
# enthralling
# entrammelled
# entrammelling
# entrapped
# entrapping
# envied
# enwound
# enwrapped
# enwrapping
# equalled
# equalling
# equipped
# equipping
# espied
# esterified
# estopped
# estopping
# etherified
# excelled
# excelling
# exemplified
# expelled
# expelling
# extolled
# extolling
# facetted
# facetting
# fagged
# fagging
# fallen
# falsified
# fancied
# fanned
# fanning
# fantasied
# fatted
# fatting
# featherbedded
# featherbedding
# fed
# feed
# fell
# felt
# ferried
# fibbed
# fibbing
# figged
# figging
# filled_up
# fine-drawn
# fine-drew
# finned
# finning
# fitted
# fitting
# flagged
# flagging
# flammed
# flamming
# flannelled
# flannelling
# flapped
# flapping
# flatted
# flatting
# fled
# flew
# flimflammed
# flimflamming
# flip-flopped
# flip-flopping
# flipped
# flipping
# flitted
# flitting
# flogged
# flogging
# floodlit
# flopped
# flopping
# flown
# flubbed
# flubbing
# flung
# flurried
# flyblew
# flyblown
# fobbed
# fobbing
# fogged
# fogging
# footslogged
# footslogging
# forbad
# forbade
# forbidden
# forbidding
# forbore
# forborne
# force-fed
# fordid
# fordone
# foredid
# foredone
# foregone
# foreknew
# foreknown
# foreran
# forerunning
# foresaw
# foreseen
# foreshown
# forespoke
# forespoken
# foretold
# forewent
# forgave
# forgetting
# forgiven
# forgone
# forgot
# forgotten
# formatted
# formatting
# forsaken
# forsook
# forspoke
# forspoken
# forswore
# forsworn
# fortified
# forwent
# fought
# found
# foxtrotted
# foxtrotting
# frapped
# frapping
# freeze-dried
# frenchified
# frenzied
# fretted
# fretting
# fried
# frigged
# frigging
# fritted
# fritting
# frivolled
# frivolling
# frogged
# frogging
# frolicked
# frolicking
# froze
# frozen
# fructified
# fuelled
# fuelling
# fulfilled
# fulfilling
# funned
# funnelled
# funnelling
# funning
# furred
# furring
# gadded
# gadding
# gagged
# gagging
# gainsaid
# gambolled
# gambolling
# gammed
# gamming
# gan
# ganned
# ganning
# gapped
# gapping
# gasified
# gassed
# gasses
# gassing
# gave
# gelled
# gelling
# gelt
# gemmed
# gemming
# genned-up
# genning-up
# gens-up
# gets_lost
# gets_started
# getting
# getting_lost
# getting_started
# ghostwritten
# ghostwrote
# gibbed
# gibbing
# giddied
# giftwrapped
# giftwrapping
# gigged
# gigging
# gilt
# ginned
# ginning
# gipped
# gipping
# girt
# given
# glommed
# glomming
# gloried
# glorified
# glutted
# glutting
# gnawn
# goes_deep
# going_deep
# gollied
# gone
# gone_deep
# goose-stepped
# goose-stepping
# got
# got_lost
# got_started
# gotten
# gotten_lost
# grabbed
# grabbing
# gratified
# gravelled
# gravelling
# graven
# grew
# grinned
# grinning
# gripped
# gripping
# gript
# gritted
# gritting
# ground
# grovelled
# grovelling
# grown
# grubbed
# grubbing
# guarantied
# gullied
# gummed
# gumming
# gunned
# gunning
# gypped
# gypping
# hacksawn
# had
# had_a_feeling
# had_left
# had_the_feeling
# hammed
# hamming
# hamstrung
# hand-knitted
# hand-knitting
# handfed
# handicapped
# handicapping
# handselled
# handselling
# harried
# has
# has_a_feeling
# has_left
# has_the_feeling
# hatchelled
# hatchelling
# hatted
# hatting
# having_a_feeling
# having_left
# having_the_feeling
# heard
# hedgehopped
# hedgehopping
# held
# hemmed
# hemming
# hewn
# hiccupped
# hiccupping
# hid
# hidden
# high-hatted
# high-hatting
# hinnied
# hitting
# hobbed
# hobbing
# hobnobbed
# hobnobbing
# hocus-pocussed
# hocus-pocussing
# hocussed
# hocussing
# hogged
# hogging
# hogtying
# honied
# hopped
# hopping
# horrified
# horsewhipped
# horsewhipping
# houselled
# houselling
# hove
# hovelled
# hovelling
# hugged
# hugging
# humbugged
# humbugging
# humidified
# hummed
# humming
# hung
# hurried
# hypertrophied
# identified
# imbedded
# imbedding
# impanelled
# impanelling
# impelled
# impelling
# implied
# inbred
# incurred
# incurring
# indemnified
# indwelt
# inferred
# inferring
# initialled
# initialling
# inlaid
# insetting
# inspanned
# inspanning
# installed
# installing
# intensified
# interbred
# intercropped
# intercropping
# intercutting
# interlaid
# interlapped
# interlapping
# intermarried
# intermitted
# intermitting
# interpled
# interred
# interring
# interstratified
# interwove
# interwoven
# intromitted
# intromitting
# inwove
# inwoven
# inwrapped
# inwrapping
# is
# jabbed
# jabbing
# jagged
# jagging
# jammed
# jamming
# japanned
# japanning
# jarred
# jarring
# jellied
# jellified
# jemmied
# jerry-built
# jetted
# jetting
# jewelled
# jewelling
# jibbed
# jibbing
# jigged
# jigging
# jimmied
# jitterbugged
# jitterbugging
# jobbed
# jobbing
# jog-trotted
# jog-trotting
# jogged
# jogging
# joined_battle
# joined_forces
# joining_battle
# joining_forces
# joins_battle
# joins_forces
# jollied
# jollified
# jotted
# jotting
# joy-ridden
# joy-rode
# joypopped
# joypopping
# jugged
# jugging
# jumped_off
# jumping_off
# jumps_off
# justified
# jutted
# jutting
# kenned
# kennelled
# kennelling
# kenning
# kent
# kept
# kernelled
# kernelling
# kidded
# kidding
# kidnapped
# kidnapping
# kipped
# kipping
# knapped
# knapping
# kneecapped
# kneecapping
# knelt
# knew
# knitted
# knitting
# knobbed
# knobbing
# knotted
# knotting
# known
# ko'd
# ko'ing
# ko's
# labelled
# labelling
# laden
# ladyfied
# ladyfies
# ladyfying
# lagged
# lagging
# laid
# lain
# lallygagged
# lallygagging
# lammed
# lamming
# lapidified
# lapped
# lapping
# laurelled
# laurelling
# lay
# layed_for
# laying_for
# lays_for
# leant
# leapfrogged
# leapfrogging
# leapt
# learnt
# leaves_undone
# leaving_undone
# led
# left
# left_undone
# lent
# letting
# levelled
# levelling
# levied
# libelled
# libelling
# lignified
# lipped
# lipping
# liquefied
# liquified
# lit
# lobbed
# lobbied
# lobbing
# logged
# logging
# looked_towards
# looking_towards
# looks_towards
# lopped
# lopping
# lost
# lotted
# lotting
# lugged
# lugging
# lullabied
# lying
# machine-gunned
# machine-gunning
# madded
# madding
# made
# magnified
# manned
# manning
# manumitted
# manumitting
# mapped
# mapping
# marcelled
# marcelling
# marred
# married
# marring
# marshalled
# marshalling
# marvelled
# marvelling
# matted
# matting
# meant
# medalled
# medalling
# met
# metalled
# metalling
# metrified
# might
# militated_against
# militates_against
# militating_against
# mimicked
# mimicking
# minified
# misapplied
# misbecame
# miscarried
# misdealt
# misfitted
# misfitting
# misgave
# misgiven
# mishitting
# mislaid
# misled
# mispled
# misspelt
# misspent
# mistaken
# mistook
# misunderstood
# mobbed
# mobbing
# modelled
# modelling
# modified
# mollified
# molten
# mopped
# mopping
# mortified
# mown
# mudded
# muddied
# mudding
# mugged
# mugging
# multiplied
# mummed
# mummified
# mumming
# mutinied
# mystified
# nabbed
# nabbing
# nagged
# nagging
# napped
# napping
# netted
# netting
# nibbed
# nibbing
# nickelled
# nickelling
# nid-nodded
# nid-nodding
# nidified
# nigrified
# nipped
# nipping
# nitrified
# nodded
# nodding
# non-prossed
# non-prosses
# non-prossing
# nonplussed
# nonplusses
# nonplussing
# notified
# nullified
# nutted
# nutting
# objectified
# occupied
# occurred
# occurring
# offsetting
# omitted
# omitting
# ossified
# outbidden
# outbidding
# outbred
# outcried
# outcropped
# outcropping
# outdid
# outdone
# outdrawn
# outdrew
# outfitted
# outfitting
# outfought
# outgassed
# outgasses
# outgassing
# outgeneralled
# outgeneralling
# outgone
# outgrew
# outgrown
# outlaid
# outmanned
# outmanning
# outputted
# outputting
# outran
# outridden
# outrode
# outrunning
# outshone
# outshot
# outsold
# outspanned
# outspanning
# outstood
# outstripped
# outstripping
# outthought
# outwent
# outwitted
# outwitting
# outwore
# outworn
# overbidden
# overbidding
# overblew
# overblown
# overbore
# overborne
# overbuilt
# overcame
# overcropped
# overcropping
# overdid
# overdone
# overdrawn
# overdrew
# overdriven
# overdrove
# overflew
# overflown
# overgrew
# overgrown
# overheard
# overhung
# overlaid
# overlain
# overlapped
# overlapping
# overlay
# overlying
# overmanned
# overmanning
# overpaid
# overpast
# overran
# overridden
# overrode
# overrunning
# oversaw
# overseen
# oversetting
# oversewn
# overshot
# oversimplified
# overslept
# oversold
# overspent
# overspilt
# overstepped
# overstepping
# overtaken
# overthrew
# overthrown
# overtook
# overtopped
# overtopping
# overwound
# overwritten
# overwrote
# pacified
# padded
# padding
# paid
# palled
# palling
# palsied
# pandied
# panelled
# panelling
# panicked
# panicking
# panned
# panning
# parallelled
# parallelling
# parcelled
# parcelling
# parodied
# parried
# partaken
# partook
# pasquil
# pasquilled
# pasquilling
# pasquils
# patrolled
# patrolling
# patted
# patting
# pedalled
# pedalling
# pegged
# pegging
# pencilled
# pencilling
# penned
# penning
# pent
# pepped
# pepping
# permitted
# permitting
# personified
# petrified
# petted
# pettifogged
# pettifogging
# petting
# phantasied
# photocopied
# photomapped
# photomapping
# photosetting
# physicked
# physicking
# picnicked
# picnicking
# pigged
# pigging
# pilloried
# pinch-hitting
# pinned
# pinning
# pipped
# pipping
# pistol-whipped
# pistol-whipping
# pistolled
# pistolling
# pitapatted
# pitapatting
# pitied
# pitted
# pitting
# planned
# planning
# platted
# platting
# played_a_part
# playing_a_part
# plays_a_part
# pled
# plied
# plodded
# plodding
# plopped
# plopping
# plotted
# plotting
# plugged
# plugging
# podded
# podding
# pommelled
# pommelling
# popes
# popped
# popping
# potted
# potting
# preachified
# precancelled
# precancelling
# preferred
# preferring
# preoccupied
# prepaid
# presignified
# pretermitted
# pretermitting
# prettied
# prettified
# pried
# prigged
# prigging
# primmed
# primming
# prodded
# prodding
# programmed
# programmes
# programming
# prologed
# prologing
# prologs
# propelled
# propelling
# prophesied
# propped
# propping
# proven
# pubbed
# pubbing
# pugged
# pugging
# pummelled
# pummelling
# punned
# punning
# pupped
# pupping
# purified
# put-putted
# put-putting
# putrefied
# puttied
# putting
# qualified
# quantified
# quarrelled
# quarrelling
# quarried
# quartersawn
# queried
# quick-froze
# quick-frozen
# quickstepped
# quickstepping
# quipped
# quipping
# quitted
# quitting
# quizzed
# quizzes
# quizzing
# ragged
# ragging
# rallied
# ramified
# rammed
# ramming
# ran
# rang
# rapped
# rappelled
# rappelling
# rapping
# rarefied
# ratified
# ratted
# ratting
# ravelled
# ravelling
# razor-cutting
# re-trod
# re-trodden
# rebelled
# rebelling
# rebuilt
# rebutted
# rebutting
# recapped
# recapping
# reclassified
# recommitted
# recommitting
# recopied
# rectified
# recurred
# recurring
# red
# red-pencilled
# red-pencilling
# redded
# redding
# redid
# redone
# referred
# referring
# refitted
# refitting
# reft
# refuelled
# refuelling
# regretted
# regretting
# reheard
# reified
# relied
# remade
# remarried
# remitted
# remitting
# rent
# repaid
# repelled
# repelling
# replevied
# replied
# repotted
# repotting
# reran
# rerunning
# resat
# resetting
# resewn
# resitting
# retaken
# rethought
# retold
# retook
# retransmitted
# retransmitting
# retried
# retrofitted
# retrofitting
# retted
# retting
# reunified
# revelled
# revelling
# revetted
# revetting
# revivified
# revved
# revving
# rewound
# rewritten
# rewrote
# ribbed
# ribbing
# ricochetted
# ricochetting
# ridded
# ridden
# ridding
# rigged
# rigging
# rigidified
# rimmed
# rimming
# ripped
# ripping
# risen
# rivalled
# rivalling
# riven
# robbed
# robbing
# rode
# rose
# rotted
# rotting
# rough-dried
# rough-hewn
# rove
# rowelled
# rowelling
# rubbed
# rubbing
# rung
# running
# rutted
# rutting
# saccharified
# sagged
# sagging
# said
# salaried
# salified
# sallied
# sanctified
# sandbagged
# sandbagging
# sang
# sank
# saponified
# sapped
# sapping
# sat
# satisfied
# savvied
# saw
# sawn
# scagged
# scagging
# scanned
# scanning
# scarified
# scarred
# scarring
# scatted
# scatting
# scorified
# scragged
# scragging
# scrammed
# scramming
# scrapped
# scrapping
# scried
# scrubbed
# scrubbing
# scrummed
# scrumming
# scudded
# scudding
# scummed
# scumming
# scurried
# seed
# seen
# sent
# setting
# sewn
# shagged
# shagging
# shaken
# shaken_hands
# shakes_hands
# shaking_hands
# shammed
# shamming
# sharecropped
# sharecropping
# shat
# shaven
# shed
# shedding
# shellacked
# shellacking
# shent
# shewn
# shied
# shikarred
# shikarring
# shillyshallied
# shimmed
# shimmied
# shimming
# shinned
# shinning
# shipped
# shipping
# shitted
# shitting
# shod
# shone
# shook
# shook_hands
# shopped
# shopping
# shot
# shotgunned
# shotgunning
# shotted
# shotting
# shovelled
# shovelling
# shown
# shrank
# shredded
# shredding
# shrink-wrapped
# shrink-wrapping
# shrivelled
# shrivelling
# shriven
# shrove
# shrugged
# shrugging
# shrunk
# shrunken
# shunned
# shunning
# shutting
# sicked
# sicking
# sideslipped
# sideslipping
# sidestepped
# sidestepping
# sightsaw
# sightseen
# signalled
# signalling
# signified
# silicified
# simplified
# singing
# single-stepped
# single-stepping
# sinned
# sinning
# sipped
# sipping
# sitting
# skellied
# skenned
# skenning
# sketted
# sketting
# ski'd
# skidded
# skidding
# skimmed
# skimming
# skin-popped
# skin-popping
# skinned
# skinning
# skinny-dipped
# skinny-dipping
# skipped
# skipping
# skivvied
# skydove
# slabbed
# slabbing
# slagged
# slagging
# slain
# slammed
# slamming
# slapped
# slapping
# slatted
# slatting
# sledding
# slept
# slew
# slid
# slidden
# slipped
# slipping
# slitting
# slogged
# slogging
# slopped
# slopping
# slotted
# slotting
# slugged
# slugging
# slummed
# slumming
# slung
# slunk
# slurred
# slurring
# smelt
# smit
# smitten
# smote
# smutted
# smutting
# snagged
# snagging
# snapped
# snapping
# snedded
# snedding
# snipped
# snipping
# snivelled
# snivelling
# snogged
# snogging
# snubbed
# snubbing
# snuck
# snugged
# snugging
# sobbed
# sobbing
# sodded
# sodding
# soft-pedalled
# soft-pedalling
# sold
# solemnified
# solidified
# soothsaid
# sopped
# sopping
# sought
# sown
# spagged
# spagging
# spancelled
# spancelling
# spanned
# spanning
# sparred
# sparring
# spat
# spatted
# spatting
# specified
# sped
# speechified
# spellbound
# spelt
# spent
# spied
# spilt
# spin-dried
# spinning
# spiralled
# spiralling
# spitted
# spitting
# splitting
# spoilt
# spoke
# spoken
# spoon-fed
# spotlit
# spotted
# spotting
# sprang
# sprigged
# sprigging
# sprung
# spudded
# spudding
# spun
# spurred
# spurring
# squatted
# squatting
# squibbed
# squibbing
# squidded
# squidding
# squilgee
# stabbed
# stabbing
# stall-fed
# stank
# starred
# starring
# steadied
# stellified
# stemmed
# stemming
# stems_from
# stencilled
# stencilling
# stepped
# stepping
# stetted
# stetting
# stied
# stilettoeing
# stirred
# stirring
# stole
# stolen
# stood
# stopped
# stopping
# storied
# stotted
# stotting
# stove
# strapped
# strapping
# stratified
# strewn
# stridden
# stripped
# stripping
# striven
# strode
# stropped
# stropping
# strove
# strown
# struck
# strummed
# strumming
# strung
# strutted
# strutting
# stubbed
# stubbing
# stuck
# studded
# studding
# studied
# stultified
# stummed
# stumming
# stung
# stunk
# stunned
# stunning
# stupefied
# stymying
# subbed
# subbing
# subjectified
# subletting
# submitted
# submitting
# subtotalled
# subtotalling
# sullied
# sulphuretted
# sulphuretting
# summed
# summing
# sung
# sunk
# sunken
# sunned
# sunning
# supped
# supping
# supplied
# swabbed
# swabbing
# swagged
# swagging
# swam
# swapped
# swapping
# swatted
# swatting
# swept
# swigged
# swigging
# swimming
# swivelled
# swivelling
# swollen
# swopped
# swopping
# swops
# swore
# sworn
# swotted
# swotting
# swum
# swung
# syllabified
# symbolled
# symbolling
# tabbed
# tabbing
# tagged
# tagging
# taken
# taken_a_side
# taken_pains
# taken_steps
# takes_a_side
# takes_pains
# takes_steps
# taking_a_side
# taking_pains
# taking_steps
# talcked
# talcking
# tallied
# tally-ho'd
# tammied
# tanned
# tanning
# tapped
# tapping
# tarred
# tarried
# tarring
# tasselled
# tasselling
# tatted
# tatting
# taught
# taxis
# taxying
# teaselled
# teaselling
# tedded
# tedding
# tepefied
# terrified
# testes
# testified
# thinking_the_world_of
# thinks_the_world_of
# thinned
# thinning
# thought
# thought_the_world_of
# threw
# threw_out
# thriven
# throbbed
# throbbing
# throve
# throwing_out
# thrown
# thrown_out
# throws_out
# thrummed
# thrumming
# thudded
# thudding
# tidied
# tinned
# tinning
# tinselled
# tinselling
# tipped
# tipping
# tittupped
# tittupping
# toadied
# togged
# togging
# told
# took
# took_a_side
# took_pains
# took_steps
# topped
# topping
# tore
# torn
# torrefied
# torrify
# totalled
# totalling
# totted
# totting
# towelled
# towelling
# trafficked
# trafficking
# trameled
# trameling
# tramelled
# tramelling
# tramels
# trammed
# tramming
# transferred
# transferring
# transfixt
# tranship
# transhipped
# transhipping
# transmitted
# transmitting
# transmogrified
# transshipped
# transshipping
# trapanned
# trapanning
# trapped
# trapping
# travelled
# travelling
# travestied
# trekked
# trekking
# trepanned
# trepanning
# tried
# trigged
# trigging
# trimmed
# trimming
# tripped
# tripping
# trod
# trodden
# trogged
# trogging
# trotted
# trotting
# trowelled
# trowelling
# tugged
# tugging
# tumefied
# tunned
# tunnelled
# tunnelling
# tunning
# tupped
# tupping
# tut-tutted
# tut-tutting
# twigged
# twigging
# twinned
# twinning
# twitted
# twitting
# tying
# typesetting
# typewritten
# typewrote
# typified
# uglified
# unbarred
# unbarring
# unbent
# unbound
# uncapped
# uncapping
# unclad
# unclogged
# unclogging
# underbidding
# underbought
# undercutting
# underfed
# undergirt
# undergone
# underlaid
# underlain
# underlay
# underletting
# underlying
# underpaid
# underpinned
# underpinning
# underpropped
# underpropping
# undersetting
# undershot
# undersold
# understood
# understudied
# undertaken
# undertook
# underwent
# underwritten
# underwrote
# undid
# undone
# unfitted
# unfitting
# unfroze
# unfrozen
# unified
# unkennelled
# unkennelling
# unknitted
# unknitting
# unlaid
# unlearnt
# unmade
# unmanned
# unmanning
# unpegged
# unpegging
# unpinned
# unpinning
# unplugged
# unplugging
# unravelled
# unravelling
# unrigged
# unrigging
# unripped
# unripping
# unrove
# unsaid
# unshipped
# unshipping
# unslung
# unsnapped
# unsnapping
# unspoke
# unspoken
# unsteadied
# unstepped
# unstepping
# unstopped
# unstopping
# unstrung
# unstuck
# unswore
# unsworn
# untaught
# unthought
# untidied
# untrod
# untrodden
# untying
# unwound
# unwrapped
# unwrapping
# unzipped
# unzipping
# upbuilt
# upheld
# uphove
# upped
# uppercutting
# upping
# uprisen
# uprose
# upsetting
# upsprang
# upsprung
# upswept
# upswollen
# upswung
# vagged
# vagging
# varied
# vatted
# vatting
# verbified
# verified
# versified
# vetted
# vetting
# victualled
# victualling
# vilified
# vitrified
# vitriolled
# vitriolling
# vivified
# vying
# wadded
# waddied
# wadding
# wadsetted
# wadsetting
# wagged
# wagging
# wanned
# wanning
# warred
# warring
# was
# water-ski'd
# waylaid
# wearied
# weatherstripped
# weatherstripping
# webbed
# webbing
# wedded
# wedding
# weed
# went
# went_deep
# wept
# were
# wetted
# wetting
# whammed
# whamming
# whapped
# whapping
# whetted
# whetting
# whinnied
# whipped
# whipping
# whipsawn
# whirred
# whirring
# whistle-stopped
# whistle-stopping
# whizzed
# whizzes
# whizzing
# whopped
# whopping
# wigged
# wigging
# wigwagged
# wigwagging
# wildcatted
# wildcatting
# window-shopped
# window-shopping
# winning
# winterfed
# wiredrawn
# wiredrew
# withdrawn
# withdrew
# withheld
# withstood
# woke
# woken
# won
# wonned
# wonning
# wore
# worn
# worried
# worshipped
# worshipping
# wound
# wove
# woven
# wrapped
# wrapping
# wried
# written
# wrote
# wrought
# wrung
# yakked
# yakking
# yapped
# yapping
# ycleped
# yclept
# yenned
# yenning
# yodelled
# yodelling
# zapped
# zapping
# zigzagged
# zigzagging
# zipped
# zipping
# adj.exc
# acer
# after
# airier
# airiest
# all-arounder
# angrier
# angriest
# archer
# artier
# artiest
# ashier
# ashiest
# assaulter
# attacker
# backer
# baggier
# baggiest
# balkier
# balkiest
# balmier
# balmiest
# bandier
# bandiest
# bargainer
# barmier
# barmiest
# battier
# battiest
# baulkier
# baulkiest
# bawdier
# bawdiest
# bayer
# beadier
# beadiest
# beastlier
# beastliest
# beater
# beefier
# beefiest
# beerier
# beeriest
# bendier
# bendiest
# best
# better
# bigger
# biggest
# bitchier
# bitchiest
# biter
# bittier
# bittiest
# blearier
# bleariest
# bloodier
# bloodiest
# bloodthirstier
# bloodthirstiest
# blowier
# blowiest
# blowsier
# blowsiest
# blowzier
# blowziest
# bluer
# bluest
# boner
# bonier
# boniest
# bonnier
# bonniest
# boozier
# booziest
# boskier
# boskiest
# bossier
# bossiest
# botchier
# botchiest
# bother
# bouncier
# bounciest
# bounder
# bower
# brainier
# brainiest
# brashier
# brashiest
# brassier
# brassiest
# brawnier
# brawniest
# breathier
# breathiest
# breezier
# breeziest
# brinier
# briniest
# britisher
# broadcaster
# brooder
# broodier
# broodiest
# bubblier
# bubbliest
# buggier
# buggiest
# bulkier
# bulkiest
# bumpier
# bumpiest
# bunchier
# bunchiest
# burlier
# burliest
# burrier
# burriest
# burster
# bushier
# bushiest
# busier
# busiest
# buster
# bustier
# bustiest
# cagier
# cagiest
# camper
# cannier
# canniest
# canter
# cantier
# cantiest
# caster
# catchier
# catchiest
# cattier
# cattiest
# cer
# chancier
# chanciest
# charier
# chariest
# chattier
# chattiest
# cheekier
# cheekiest
# cheerier
# cheeriest
# cheesier
# cheesiest
# chestier
# chestiest
# chewier
# chewiest
# chillier
# chilliest
# chintzier
# chintziest
# chippier
# chippiest
# choosier
# choosiest
# choppier
# choppiest
# chubbier
# chubbiest
# chuffier
# chuffiest
# chummier
# chummiest
# chunkier
# chunkiest
# churchier
# churchiest
# clammier
# clammiest
# classier
# classiest
# cleanlier
# cleanliest
# clerklier
# clerkliest
# cloudier
# cloudiest
# clubbier
# clubbiest
# clumsier
# clumsiest
# cockier
# cockiest
# coder
# collier
# colliest
# comelier
# comeliest
# comfier
# comfiest
# cornier
# corniest
# cosier
# cosiest
# costlier
# costliest
# costumer
# counterfeiter
# courtlier
# courtliest
# cozier
# coziest
# crabbier
# crabbiest
# cracker
# craftier
# craftiest
# craggier
# craggiest
# crankier
# crankiest
# crasher
# crawlier
# crawliest
# crazier
# craziest
# creamer
# creamier
# creamiest
# creepier
# creepiest
# crispier
# crispiest
# crumbier
# crumbiest
# crumblier
# crumbliest
# crummier
# crummiest
# crustier
# crustiest
# curlier
# curliest
# customer
# cuter
# daffier
# daffiest
# daintier
# daintiest
# dandier
# dandiest
# deadlier
# deadliest
# dealer
# deserter
# dewier
# dewiest
# dicier
# diciest
# dimer
# dimmer
# dimmest
# dingier
# dingiest
# dinkier
# dinkiest
# dippier
# dippiest
# dirtier
# dirtiest
# dishier
# dishiest
# dizzier
# dizziest
# dodgier
# dodgiest
# dopier
# dopiest
# dottier
# dottiest
# doughier
# doughiest
# doughtier
# doughtiest
# dowdier
# dowdiest
# dowier
# dowiest
# downer
# downier
# downiest
# dozier
# doziest
# drabber
# drabbest
# draftier
# draftiest
# draggier
# draggiest
# draughtier
# draughtiest
# dreamier
# dreamiest
# drearier
# dreariest
# dreggier
# dreggiest
# dresser
# dressier
# dressiest
# drier
# driest
# drippier
# drippiest
# drowsier
# drowsiest
# dryer
# dryest
# dumpier
# dumpiest
# dunner
# dunnest
# duskier
# duskiest
# dustier
# dustiest
# earlier
# earliest
# earthier
# earthiest
# earthlier
# earthliest
# easier
# easiest
# easter
# eastsider
# edger
# edgier
# edgiest
# eerier
# eeriest
# emptier
# emptiest
# faker
# fancier
# fanciest
# fatter
# fattest
# fattier
# fattiest
# faultier
# faultiest
# feistier
# feistiest
# feller
# fiddlier
# fiddliest
# filmier
# filmiest
# filthier
# filthiest
# finnier
# finniest
# first-rater
# first-stringer
# fishier
# fishiest
# fitter
# fittest
# flabbier
# flabbiest
# flaggier
# flaggiest
# flakier
# flakiest
# flasher
# flashier
# flashiest
# flatter
# flattest
# flauntier
# flauntiest
# fledgier
# fledgiest
# fleecier
# fleeciest
# fleshier
# fleshiest
# fleshlier
# fleshliest
# flightier
# flightiest
# flimsier
# flimsiest
# flintier
# flintiest
# floatier
# floatiest
# floppier
# floppiest
# flossier
# flossiest
# fluffier
# fluffiest
# flukier
# flukiest
# foamier
# foamiest
# foggier
# foggiest
# folder
# folksier
# folksiest
# foolhardier
# foolhardiest
# fore-and-after
# foreigner
# forest
# founder
# foxier
# foxiest
# fratchier
# fratchiest
# freakier
# freakiest
# freer
# freest
# frenchier
# frenchiest
# friendlier
# friendliest
# friskier
# friskiest
# frizzier
# frizziest
# frizzlier
# frizzliest
# frostier
# frostiest
# frouzier
# frouziest
# frowsier
# frowsiest
# frowzier
# frowziest
# fruitier
# fruitiest
# funkier
# funkiest
# funnier
# funniest
# furrier
# furriest
# fussier
# fussiest
# fustier
# fustiest
# fuzzier
# fuzziest
# gabbier
# gabbiest
# gamier
# gamiest
# gammier
# gammiest
# gassier
# gassiest
# gaudier
# gaudiest
# gauzier
# gauziest
# gawkier
# gawkiest
# ghastlier
# ghastliest
# ghostlier
# ghostliest
# giddier
# giddiest
# gladder
# gladdest
# glassier
# glassiest
# glibber
# glibbest
# gloomier
# gloomiest
# glossier
# glossiest
# glummer
# glummest
# godlier
# godliest
# goer
# goner
# goodlier
# goodliest
# goofier
# goofiest
# gooier
# gooiest
# goosier
# goosiest
# gorier
# goriest
# gradelier
# gradeliest
# grader
# grainier
# grainiest
# grassier
# grassiest
# greasier
# greasiest
# greedier
# greediest
# grimmer
# grimmest
# grislier
# grisliest
# grittier
# grittiest
# grizzlier
# grizzliest
# groggier
# groggiest
# groovier
# grooviest
# grottier
# grottiest
# grounder
# grouper
# groutier
# groutiest
# grubbier
# grubbiest
# grumpier
# grumpiest
# guest
# guiltier
# guiltiest
# gummier
# gummiest
# gushier
# gushiest
# gustier
# gustiest
# gutsier
# gutsiest
# hairier
# hairiest
# halfways
# halter
# hammier
# hammiest
# handier
# handiest
# happier
# happiest
# hardier
# hardiest
# hastier
# hastiest
# haughtier
# haughtiest
# hazier
# haziest
# header
# headier
# headiest
# healthier
# healthiest
# heartier
# heartiest
# heavier
# heaviest
# heftier
# heftiest
# hepper
# heppest
# herbier
# herbiest
# hinder
# hipper
# hippest
# hippier
# hippiest
# hoarier
# hoariest
# holier
# holiest
# homelier
# homeliest
# homer
# homier
# homiest
# hornier
# horniest
# horsier
# horsiest
# hotter
# hottest
# humpier
# humpiest
# hunger
# hungrier
# hungriest
# huskier
# huskiest
# icier
# iciest
# inkier
# inkiest
# insider
# interest
# jaggier
# jaggiest
# jammier
# jammiest
# jauntier
# jauntiest
# jazzier
# jazziest
# jerkier
# jerkiest
# jointer
# jollier
# jolliest
# juicier
# juiciest
# jumpier
# jumpiest
# kindlier
# kindliest
# kinkier
# kinkiest
# knottier
# knottiest
# knurlier
# knurliest
# kookier
# kookiest
# lacier
# laciest
# lairier
# lairiest
# lakier
# lakiest
# lander
# lankier
# lankiest
# lathier
# lathiest
# layer
# lazier
# laziest
# leafier
# leafiest
# leakier
# leakiest
# learier
# leariest
# leer
# leerier
# leeriest
# left-hander
# left-winger
# leggier
# leggiest
# lengthier
# lengthiest
# ler
# leveler
# limier
# limiest
# lippier
# lippiest
# liter
# livelier
# liveliest
# liver
# loather
# loftier
# loftiest
# logier
# logiest
# lonelier
# loneliest
# loner
# loonier
# looniest
# loopier
# loopiest
# lordlier
# lordliest
# lousier
# lousiest
# lovelier
# loveliest
# lowlander
# lowlier
# lowliest
# luckier
# luckiest
# lumpier
# lumpiest
# lunier
# luniest
# lustier
# lustiest
# madder
# maddest
# mainer
# maligner
# maltier
# maltiest
# mangier
# mangiest
# mankier
# mankiest
# manlier
# manliest
# mariner
# marshier
# marshiest
# massier
# massiest
# matter
# maungier
# maungiest
# mazier
# maziest
# mealier
# mealiest
# measlier
# measliest
# meatier
# meatiest
# meeter
# merrier
# merriest
# messier
# messiest
# miffier
# miffiest
# mightier
# mightiest
# milcher
# milker
# milkier
# milkiest
# mingier
# mingiest
# minter
# mirkier
# mirkiest
# miser
# mistier
# mistiest
# mocker
# modeler
# modest
# moldier
# moldiest
# moodier
# moodiest
# moonier
# mooniest
# mothier
# mothiest
# mouldier
# mouldiest
# mousier
# mousiest
# mouthier
# mouthiest
# muckier
# muckiest
# muddier
# muddiest
# muggier
# muggiest
# multiplexer
# murkier
# murkiest
# mushier
# mushiest
# muskier
# muskiest
# muster
# mustier
# mustiest
# muzzier
# muzziest
# nappier
# nappiest
# nastier
# nastiest
# nattier
# nattiest
# naughtier
# naughtiest
# needier
# neediest
# nervier
# nerviest
# newsier
# newsiest
# niftier
# niftiest
# nippier
# nippiest
# nittier
# nittiest
# noisier
# noisiest
# northeasterner
# norther
# northerner
# nosier
# nosiest
# number
# nuttier
# nuttiest
# offer
# offer
# oilier
# oiliest
# old-timer
# oliver
# oozier
# ooziest
# opener
# outsider
# overcomer
# overnighter
# owner
# pallier
# palliest
# palmier
# palmiest
# paltrier
# paltriest
# pappier
# pappiest
# parkier
# parkiest
# part-timer
# passer
# paster
# pastier
# pastiest
# patchier
# patchiest
# pater
# pawkier
# pawkiest
# peachier
# peachiest
# pearler
# pearlier
# pearliest
# pedaler
# peppier
# peppiest
# perkier
# perkiest
# peskier
# peskiest
# peter
# pettier
# pettiest
# phonier
# phoniest
# pickier
# pickiest
# piggier
# piggiest
# pinier
# piniest
# pitchier
# pitchiest
# pithier
# pithiest
# planer
# plashier
# plashiest
# platier
# platiest
# player
# pluckier
# pluckiest
# plumber
# plumier
# plumiest
# plummier
# plummiest
# podgier
# podgiest
# pokier
# pokiest
# polisher
# porkier
# porkiest
# porter
# portlier
# portliest
# poster
# pottier
# pottiest
# preachier
# preachiest
# presenter
# pretender
# prettier
# prettiest
# pricier
# priciest
# pricklier
# prickliest
# priestlier
# priestliest
# primer
# primmer
# primmest
# princelier
# princeliest
# printer
# prissier
# prissiest
# privateer
# privier
# priviest
# prompter
# prosier
# prosiest
# pudgier
# pudgiest
# puffer
# puffier
# puffiest
# pulpier
# pulpiest
# punchier
# punchiest
# punier
# puniest
# pushier
# pushiest
# pussier
# pussiest
# quaggier
# quaggiest
# quakier
# quakiest
# queasier
# queasiest
# queenlier
# queenliest
# racier
# raciest
# rainier
# rainiest
# randier
# randiest
# rangier
# rangiest
# ranker
# rattier
# rattiest
# rattlier
# rattliest
# raunchier
# raunchiest
# readier
# readiest
# recorder
# redder
# reddest
# reedier
# reediest
# renter
# retailer
# right-hander
# right-winger
# rimier
# rimiest
# riskier
# riskiest
# ritzier
# ritziest
# roaster
# rockier
# rockiest
# roilier
# roiliest
# rookier
# rookiest
# roomier
# roomiest
# ropier
# ropiest
# rosier
# rosiest
# rowdier
# rowdiest
# ruddier
# ruddiest
# runnier
# runniest
# rusher
# rushier
# rushiest
# rustier
# rustiest
# ruttier
# ruttiest
# sadder
# saddest
# salter
# saltier
# saltiest
# sampler
# sandier
# sandiest
# sappier
# sappiest
# sassier
# sassiest
# saucier
# sauciest
# savvier
# savviest
# scabbier
# scabbiest
# scalier
# scaliest
# scantier
# scantiest
# scarier
# scariest
# scraggier
# scraggiest
# scragglier
# scraggliest
# scraper
# scrappier
# scrappiest
# scrawnier
# scrawniest
# screwier
# screwiest
# scrubbier
# scrubbiest
# scruffier
# scruffiest
# scungier
# scungiest
# scurvier
# scurviest
# seamier
# seamiest
# second-rater
# seconder
# seedier
# seediest
# seemlier
# seemliest
# serer
# sexier
# sexiest
# shabbier
# shabbiest
# shadier
# shadiest
# shaggier
# shaggiest
# shakier
# shakiest
# shapelier
# shapeliest
# shier
# shiest
# shiftier
# shiftiest
# shinier
# shiniest
# shirtier
# shirtiest
# shoddier
# shoddiest
# showier
# showiest
# shrubbier
# shrubbiest
# shyer
# shyest
# sicklier
# sickliest
# sightlier
# sightliest
# signaler
# signer
# silkier
# silkiest
# sillier
# silliest
# sketchier
# sketchiest
# skewer
# skimpier
# skimpiest
# skinnier
# skinniest
# slaphappier
# slaphappiest
# slatier
# slatiest
# slaver
# sleazier
# sleaziest
# sleepier
# sleepiest
# slier
# sliest
# slimier
# slimiest
# slimmer
# slimmest
# slimsier
# slimsiest
# slinkier
# slinkiest
# slippier
# slippiest
# sloppier
# sloppiest
# slyer
# slyest
# smarmier
# smarmiest
# smellier
# smelliest
# smokier
# smokiest
# smugger
# smuggest
# snakier
# snakiest
# snappier
# snappiest
# snatchier
# snatchiest
# snazzier
# snazziest
# sneaker
# sniffier
# sniffiest
# snootier
# snootiest
# snottier
# snottiest
# snowier
# snowiest
# snuffer
# snuffier
# snuffiest
# snugger
# snuggest
# soapier
# soapiest
# soggier
# soggiest
# solder
# sonsier
# sonsiest
# sootier
# sootiest
# soppier
# soppiest
# sorrier
# sorriest
# soupier
# soupiest
# souther
# southerner
# speedier
# speediest
# spicier
# spiciest
# spiffier
# spiffiest
# spikier
# spikiest
# spindlier
# spindliest
# spinier
# spiniest
# splashier
# splashiest
# spongier
# spongiest
# spookier
# spookiest
# spoonier
# spooniest
# sportier
# sportiest
# spottier
# spottiest
# spreader
# sprier
# spriest
# sprightlier
# sprightliest
# springer
# springier
# springiest
# squashier
# squashiest
# squatter
# squattest
# squattier
# squattiest
# squiffier
# squiffiest
# stagier
# stagiest
# stalkier
# stalkiest
# stapler
# starchier
# starchiest
# starer
# starest
# starrier
# starriest
# statelier
# stateliest
# steadier
# steadiest
# stealthier
# stealthiest
# steamier
# steamiest
# stingier
# stingiest
# stiper
# stocker
# stockier
# stockiest
# stodgier
# stodgiest
# stonier
# stoniest
# stormier
# stormiest
# streakier
# streakiest
# streamier
# streamiest
# stretcher
# stretchier
# stretchiest
# stringier
# stringiest
# stripier
# stripiest
# stronger
# strongest
# stroppier
# stroppiest
# stuffier
# stuffiest
# stumpier
# stumpiest
# sturdier
# sturdiest
# submariner
# sulkier
# sulkiest
# sultrier
# sultriest
# sunnier
# sunniest
# surlier
# surliest
# swagger
# swankier
# swankiest
# swarthier
# swarthiest
# sweatier
# sweatiest
# tackier
# tackiest
# talkier
# talkiest
# tangier
# tangiest
# tanner
# tannest
# tardier
# tardiest
# tastier
# tastiest
# tattier
# tattiest
# tawdrier
# tawdriest
# techier
# techiest
# teenager
# teenier
# teeniest
# teetotaler
# tester
# testier
# testiest
# tetchier
# tetchiest
# thinner
# thinnest
# third-rater
# thirstier
# thirstiest
# thornier
# thorniest
# threadier
# threadiest
# thriftier
# thriftiest
# throatier
# throatiest
# tidier
# tidiest
# timelier
# timeliest
# tinier
# tiniest
# tinnier
# tinniest
# tipsier
# tipsiest
# tonier
# toniest
# toothier
# toothiest
# toper
# touchier
# touchiest
# trader
# trashier
# trashiest
# trendier
# trendiest
# trickier
# trickiest
# tricksier
# tricksiest
# trimer
# trimmer
# trimmest
# truer
# truest
# trustier
# trustiest
# tubbier
# tubbiest
# turfier
# turfiest
# tweedier
# tweediest
# twiggier
# twiggiest
# uglier
# ugliest
# unfriendlier
# unfriendliest
# ungainlier
# ungainliest
# ungodlier
# ungodliest
# unhappier
# unhappiest
# unhealthier
# unhealthiest
# unholier
# unholiest
# unrulier
# unruliest
# untidier
# untidiest
# vastier
# vastiest
# vest
# viewier
# viewiest
# wackier
# wackiest
# wanner
# wannest
# warier
# wariest
# washier
# washiest
# waster
# wavier
# waviest
# waxier
# waxiest
# weaklier
# weakliest
# wealthier
# wealthiest
# wearier
# weariest
# webbier
# webbiest
# weedier
# weediest
# weenier
# weeniest
# weensier
# weensiest
# weepier
# weepiest
# weightier
# weightiest
# welsher
# wetter
# wettest
# whackier
# whackiest
# whimsier
# whimsiest
# wholesaler
# wieldier
# wieldiest
# wilier
# wiliest
# windier
# windiest
# winier
# winiest
# winterier
# winteriest
# wintrier
# wintriest
# wirier
# wiriest
# wispier
# wispiest
# wittier
# wittiest
# wonkier
# wonkiest
# woodier
# woodiest
# woodsier
# woodsiest
# woollier
# woolliest
# woozier
# wooziest
# wordier
# wordiest
# worldlier
# worldliest
# wormier
# wormiest
# worse
# worst
# worthier
# worthiest
# wrier
# wriest
# wryer
# wryest
# yarer
# yarest
# yeastier
# yeastiest
# younger
# youngest
# yummier
# yummiest
# zanier
# zaniest
# zippier
# zippiest
# adv.exc
# best
# better
# deeper
# farther
# further
# harder
# hardest

# %% [markdown]
# Switch to the content directory with the following code

# %%
cd /content/
# Out:
# /content

# %% [markdown]
# ## 1. Clone the BERTSUM repository:

# %%
# !git clone https://github.com/nlpyang/BertSum.git
# Out:
# Cloning into 'BertSum'...
# remote: Enumerating objects: 301, done.
# remote: Counting objects: 100% (293/293), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 301 (delta 165), reused 290 (delta 164), pack-reused 8 (from 1)
# Receiving objects: 100% (301/301), 15.05 MiB | 14.25 MiB/s, done.
# Resolving deltas: 100% (165/165), done.

# %%
# !ls -lt BertSum/
# Out:
# total 56
# drwxr-xr-x 2 root root  4096 May 11 13:31 urls
# drwxr-xr-x 5 root root  4096 May 11 13:31 src
# drwxr-xr-x 2 root root  4096 May 11 13:31 json_data
# drwxr-xr-x 2 root root  4096 May 11 13:31 logs
# drwxr-xr-x 2 root root  4096 May 11 13:31 models
# drwxr-xr-x 2 root root  4096 May 11 13:31 raw_data
# drwxr-xr-x 2 root root  4096 May 11 13:31 results
# -rw-r--r-- 1 root root   313 May 11 13:31 bert_config_uncased_base.json
# drwxr-xr-x 2 root root  4096 May 11 13:31 bert_data
# -rw-r--r-- 1 root root 11357 May 11 13:31 LICENSE
# -rw-r--r-- 1 root root  5248 May 11 13:31 README.md

# %% [markdown]
# Now switch to the bert_data directory:

# %%
cd /content/BertSum/bert_data/
# Out:
# /content/BertSum/bert_data

# %% [markdown]
# ## 2. Download the CNN/DailyMail Dataset
#
# The researchers have made the preprocessed CNN/DailyMail news dataset accessible. Therefore, our first step is to download it.
#
# Please download either the subset [bertsum_data.zip](https://drive.google.com/file/d/108C5QohdhM9T3oe1GypAberdOLqF12P0/view?usp=sharing) or the full dataset [bertsum_data.zip](https://drive.google.com/uc?id=1x0d61LP9UAN389YN00z0Pv-7jQgirVg6&export=download) and upload it to the directory /content/BertSum/bert_data/.

# %%
#from googleDriveFileDownloader import googleDriveFileDownloader
#gdrive = googleDriveFileDownloader()
#gdrive.downloadFile("https://drive.google.com/uc?id=1x0d61LP9UAN389YN00z0Pv-7jQgirVg6&export=download")
# !du -h bertsum_data.zip
# !unzip bertsum_data.zip
# !mv bertsum_data/* .
# Out:
# 223M	bertsum_data.zip
# Archive:  bertsum_data.zip
#    creating: bertsum_data/
#   inflating: bertsum_data/cnndm.test.0.bert.pt
#   inflating: bertsum_data/cnndm.test.1.bert.pt
#   inflating: bertsum_data/cnndm.test.2.bert.pt
#   inflating: bertsum_data/cnndm.test.3.bert.pt
#   inflating: bertsum_data/cnndm.test.4.bert.pt
#   inflating: bertsum_data/cnndm.test.5.bert.pt
#   inflating: bertsum_data/cnndm.train.0.bert.pt
#   inflating: bertsum_data/cnndm.train.1.bert.pt
#   inflating: bertsum_data/cnndm.train.10.bert.pt
#   inflating: bertsum_data/cnndm.train.11.bert.pt
#   inflating: bertsum_data/cnndm.train.12.bert.pt
#   inflating: bertsum_data/cnndm.train.13.bert.pt
#   inflating: bertsum_data/cnndm.train.14.bert.pt
#   inflating: bertsum_data/cnndm.train.15.bert.pt
#   inflating: bertsum_data/cnndm.train.16.bert.pt
#   inflating: bertsum_data/cnndm.train.17.bert.pt
#   inflating: bertsum_data/cnndm.train.18.bert.pt
#   inflating: bertsum_data/cnndm.train.19.bert.pt
#   inflating: bertsum_data/cnndm.train.2.bert.pt
#   inflating: bertsum_data/cnndm.train.20.bert.pt
#   inflating: bertsum_data/cnndm.train.21.bert.pt
#   inflating: bertsum_data/cnndm.train.22.bert.pt
#   inflating: bertsum_data/cnndm.train.23.bert.pt
#   inflating: bertsum_data/cnndm.train.24.bert.pt
#   inflating: bertsum_data/cnndm.train.25.bert.pt
#   inflating: bertsum_data/cnndm.train.26.bert.pt
#   inflating: bertsum_data/cnndm.train.27.bert.pt
#   inflating: bertsum_data/cnndm.train.28.bert.pt
#   inflating: bertsum_data/cnndm.train.29.bert.pt
#   inflating: bertsum_data/cnndm.train.3.bert.pt
#   inflating: bertsum_data/cnndm.train.30.bert.pt
#   inflating: bertsum_data/cnndm.train.4.bert.pt
#   inflating: bertsum_data/cnndm.train.5.bert.pt
#   inflating: bertsum_data/cnndm.train.6.bert.pt
#   inflating: bertsum_data/cnndm.train.7.bert.pt
#   inflating: bertsum_data/cnndm.train.8.bert.pt
#   inflating: bertsum_data/cnndm.train.9.bert.pt
#   inflating: bertsum_data/cnndm.valid.0.bert.pt
#   inflating: bertsum_data/cnndm.valid.1.bert.pt
#   inflating: bertsum_data/cnndm.valid.2.bert.pt
#   inflating: bertsum_data/cnndm.valid.3.bert.pt
#   inflating: bertsum_data/cnndm.valid.4.bert.pt
#   inflating: bertsum_data/cnndm.valid.5.bert.pt
#   inflating: bertsum_data/cnndm.valid.6.bert.pt

# %%
cd /content/BertSum/src
# Out:
# /content/BertSum/src

# %%
# !nvidia-smi
# Out:
# Mon May 11 13:43:01 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 3. Model Training
#
# Begin training the BERTSUM model. The code below includes the argument -encoder classifier, indicating that the BERTSUM model is being trained using a classifier.
#
# Please change lines 31 and 34 in /content/BertSum/src/models/data_loader.py. Replace `mask = 1 - (src == 0)` with `mask = ~(src == 0)` and replace `mask_cls = 1 - (clss == 0)` with `mask_cls = ~(clss == 0)`.

# %%
# %%shell
# sed -i 's/mask = 1 - (src == 0)/mask = ~(src == 0)/g' models/data_loader.py
# sed -i 's/mask_cls = 1 - (clss == 0)/mask_cls = ~(clss == 0)/g' models/data_loader.py

# %%
# %%shell
# sed -i 's/mask_cls = 1 - (clss == -1)/mask_cls = ~(clss == -1)/g' models/data_loader.py

# %%
# %%shell
# pip uninstall protobuf -y
# pip install "protobuf<3.21"
# Out:
# Found existing installation: protobuf 3.20.3
# Uninstalling protobuf-3.20.3:
#   Successfully uninstalled protobuf-3.20.3
# Collecting protobuf<3.21
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Installing collected packages: protobuf
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.20.0 requires protobuf>=5.28.0, but you have protobuf 3.20.3 which is incompatible.
# grpc-google-iam-v1 0.14.4 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-firestore 2.27.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-resource-manager 1.17.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-api-core 2.30.3 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# wandb 0.26.1 requires protobuf!=5.28.0,!=5.29.0,<8,>4.21.0, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-datastore 2.24.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-audit-log 0.5.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-logging 3.15.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-trace 1.19.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-spanner 3.65.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-appengine-logging 1.9.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-iam 2.22.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-pubsub 2.37.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-monitoring 2.30.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-speech 2.38.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-dataproc 5.27.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-dataplex 2.18.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-bigquery-storage 2.37.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-translate 3.26.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-language 2.20.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-secret-manager 2.27.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# proto-plus 1.27.2 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# googleapis-common-protos 1.74.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-bigquery-connection 1.21.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# google-cloud-functions 1.23.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.17.3 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3

# %%
# !python train.py -mode train -encoder classifier \
          -dropout 0.1 -bert_data_path ../bert_data/cnndm \
          -model_path ../models/bert_classifier -lr 2e-3 \
          -visible_gpus 0 -gpu_ranks 0 \
          -world_size 1 -report_every 50 \
          -save_checkpoint_steps 500 \
          -batch_size 6000 -decay_method noam \
          -train_steps 2000 -accum_count 2 \
          -log_file ../logs/bert_classifier \
          -use_interval true -warmup_steps 1000
# Out:
# [2026-05-11 13:51:43,854 INFO] Device ID 0
# [2026-05-11 13:51:43,854 INFO] Device cuda
# [2026-05-11 13:51:44,417 INFO] loading archive file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased.tar.gz from cache at ../temp/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba
# [2026-05-11 13:51:44,418 INFO] extracting archive file ../temp/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba to temp dir /tmp/tmpw_k46vw3
# [2026-05-11 13:51:48,639 INFO] Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# [2026-05-11 13:51:51,504 INFO] Summarizer(
#   (bert): Bert(
#     (model): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): BertLayerNorm()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#   )
#   (encoder): Classifier(
#     (linear1): Linear(in_features=768, out_features=1, bias=True)
#     (sigmoid): Sigmoid()
#   )
# )
# gpu_rank 0
# [2026-05-11 13:51:51,508 INFO] * number of parameters: 109483009
# [2026-05-11 13:51:51,508 INFO] Start training...
# [2026-05-11 13:51:54,102 INFO] Loading train dataset from ../bert_data/cnndm.train.4.bert.pt, number of examples: 2001
# [2026-05-11 13:53:53,911 INFO] Step 50/ 2000; xent: 4.85; lr: 0.0000032;  18 docs/s;    120 sec
# [2026-05-11 13:55:42,838 INFO] Loading train dataset from ../bert_data/cnndm.train.16.bert.pt, number of examples: 2001
# [2026-05-11 13:56:06,044 INFO] Step 100/ 2000; xent: 3.29; lr: 0.0000063;  16 docs/s;    252 sec
# [2026-05-11 13:58:14,910 INFO] Step 150/ 2000; xent: 3.28; lr: 0.0000095;  17 docs/s;    381 sec
# [2026-05-11 13:59:41,351 INFO] Loading train dataset from ../bert_data/cnndm.train.19.bert.pt, number of examples: 2000
# [2026-05-11 14:00:27,981 INFO] Step 200/ 2000; xent: 3.24; lr: 0.0000126;  17 docs/s;    514 sec
# [2026-05-11 14:02:36,711 INFO] Step 250/ 2000; xent: 3.30; lr: 0.0000158;  17 docs/s;    643 sec
# [2026-05-11 14:03:38,752 INFO] Loading train dataset from ../bert_data/cnndm.train.27.bert.pt, number of examples: 2001
# [2026-05-11 14:04:49,473 INFO] Step 300/ 2000; xent: 3.14; lr: 0.0000190;  16 docs/s;    775 sec
# [2026-05-11 14:06:58,703 INFO] Step 350/ 2000; xent: 3.13; lr: 0.0000221;  17 docs/s;    905 sec
# [2026-05-11 14:07:39,950 INFO] Loading train dataset from ../bert_data/cnndm.train.14.bert.pt, number of examples: 1998
# [2026-05-11 14:09:11,065 INFO] Step 400/ 2000; xent: 3.02; lr: 0.0000253;  17 docs/s;   1037 sec
# [2026-05-11 14:11:20,949 INFO] Step 450/ 2000; xent: 2.99; lr: 0.0000285;  17 docs/s;   1167 sec
# [2026-05-11 14:11:36,738 INFO] Loading train dataset from ../bert_data/cnndm.train.22.bert.pt, number of examples: 1999
# [2026-05-11 14:13:33,252 INFO] Step 500/ 2000; xent: 3.02; lr: 0.0000316;  17 docs/s;   1299 sec
# [2026-05-11 14:13:33,254 INFO] Saving checkpoint ../models/bert_classifier/model_step_500.pt
# [2026-05-11 14:15:44,607 INFO] Loading train dataset from ../bert_data/cnndm.train.13.bert.pt, number of examples: 2001
# [2026-05-11 14:15:55,127 INFO] Step 550/ 2000; xent: 2.94; lr: 0.0000348;  16 docs/s;   1441 sec
# [2026-05-11 14:18:03,324 INFO] Step 600/ 2000; xent: 3.02; lr: 0.0000379;  17 docs/s;   1569 sec
# [2026-05-11 14:19:43,636 INFO] Loading train dataset from ../bert_data/cnndm.train.28.bert.pt, number of examples: 2000
# [2026-05-11 14:20:14,488 INFO] Step 650/ 2000; xent: 2.93; lr: 0.0000411;  17 docs/s;   1700 sec
# [2026-05-11 14:22:24,421 INFO] Step 700/ 2000; xent: 2.95; lr: 0.0000443;  17 docs/s;   1830 sec
# [2026-05-11 14:23:41,695 INFO] Loading train dataset from ../bert_data/cnndm.train.5.bert.pt, number of examples: 2001
# [2026-05-11 14:24:37,063 INFO] Step 750/ 2000; xent: 2.89; lr: 0.0000474;  17 docs/s;   1963 sec
# [2026-05-11 14:26:46,071 INFO] Step 800/ 2000; xent: 2.97; lr: 0.0000506;  17 docs/s;   2092 sec
# [2026-05-11 14:27:40,099 INFO] Loading train dataset from ../bert_data/cnndm.train.10.bert.pt, number of examples: 2001
# [2026-05-11 14:28:58,106 INFO] Step 850/ 2000; xent: 2.90; lr: 0.0000538;  17 docs/s;   2224 sec
# [2026-05-11 14:31:08,417 INFO] Step 900/ 2000; xent: 2.92; lr: 0.0000569;  17 docs/s;   2354 sec
# [2026-05-11 14:31:39,697 INFO] Loading train dataset from ../bert_data/cnndm.train.29.bert.pt, number of examples: 1999
# [2026-05-11 14:33:20,789 INFO] Step 950/ 2000; xent: 2.89; lr: 0.0000601;  17 docs/s;   2487 sec
# [2026-05-11 14:35:29,103 INFO] Step 1000/ 2000; xent: 2.86; lr: 0.0000632;  17 docs/s;   2615 sec
# [2026-05-11 14:35:29,105 INFO] Saving checkpoint ../models/bert_classifier/model_step_1000.pt
# [2026-05-11 14:36:00,056 INFO] Loading train dataset from ../bert_data/cnndm.train.6.bert.pt, number of examples: 2001
# [2026-05-11 14:38:06,124 INFO] Step 1050/ 2000; xent: 2.88; lr: 0.0000617;  14 docs/s;   2772 sec
# [2026-05-11 14:39:59,448 INFO] Loading train dataset from ../bert_data/cnndm.train.25.bert.pt, number of examples: 2001
# [2026-05-11 14:40:17,754 INFO] Step 1100/ 2000; xent: 2.89; lr: 0.0000603;  17 docs/s;   2904 sec
# [2026-05-11 14:42:26,204 INFO] Step 1150/ 2000; xent: 2.86; lr: 0.0000590;  17 docs/s;   3032 sec
# [2026-05-11 14:43:58,874 INFO] Loading train dataset from ../bert_data/cnndm.train.26.bert.pt, number of examples: 2000
# [2026-05-11 14:44:37,996 INFO] Step 1200/ 2000; xent: 2.84; lr: 0.0000577;  17 docs/s;   3164 sec
# [2026-05-11 14:46:48,133 INFO] Step 1250/ 2000; xent: 2.90; lr: 0.0000566;  17 docs/s;   3294 sec
# [2026-05-11 14:47:57,475 INFO] Loading train dataset from ../bert_data/cnndm.train.30.bert.pt, number of examples: 1997
# [2026-05-11 14:48:59,284 INFO] Step 1300/ 2000; xent: 2.87; lr: 0.0000555;  17 docs/s;   3425 sec
# [2026-05-11 14:51:09,468 INFO] Step 1350/ 2000; xent: 2.83; lr: 0.0000544;  17 docs/s;   3555 sec
# [2026-05-11 14:51:56,679 INFO] Loading train dataset from ../bert_data/cnndm.train.15.bert.pt, number of examples: 1999
# [2026-05-11 14:53:22,414 INFO] Step 1400/ 2000; xent: 2.83; lr: 0.0000535;  17 docs/s;   3688 sec
# [2026-05-11 14:55:31,399 INFO] Step 1450/ 2000; xent: 2.81; lr: 0.0000525;  17 docs/s;   3817 sec
# [2026-05-11 14:55:56,168 INFO] Loading train dataset from ../bert_data/cnndm.train.9.bert.pt, number of examples: 1999
# [2026-05-11 14:57:44,445 INFO] Step 1500/ 2000; xent: 2.88; lr: 0.0000516;  16 docs/s;   3950 sec
# [2026-05-11 14:57:44,447 INFO] Saving checkpoint ../models/bert_classifier/model_step_1500.pt
# [2026-05-11 15:00:13,678 INFO] Loading train dataset from ../bert_data/cnndm.train.8.bert.pt, number of examples: 2000
# [2026-05-11 15:00:16,277 INFO] Step 1550/ 2000; xent: 2.85; lr: 0.0000508;  15 docs/s;   4102 sec
# [2026-05-11 15:02:25,623 INFO] Step 1600/ 2000; xent: 2.78; lr: 0.0000500;  17 docs/s;   4232 sec
# [2026-05-11 15:04:10,400 INFO] Loading train dataset from ../bert_data/cnndm.train.12.bert.pt, number of examples: 2001
# [2026-05-11 15:04:36,645 INFO] Step 1650/ 2000; xent: 2.89; lr: 0.0000492;  17 docs/s;   4363 sec
# [2026-05-11 15:06:46,986 INFO] Step 1700/ 2000; xent: 2.85; lr: 0.0000485;  17 docs/s;   4493 sec
# [2026-05-11 15:08:09,714 INFO] Loading train dataset from ../bert_data/cnndm.train.1.bert.pt, number of examples: 2001
# [2026-05-11 15:08:58,458 INFO] Step 1750/ 2000; xent: 2.87; lr: 0.0000478;  17 docs/s;   4624 sec
# [2026-05-11 15:11:07,853 INFO] Step 1800/ 2000; xent: 2.84; lr: 0.0000471;  17 docs/s;   4754 sec
# [2026-05-11 15:12:07,995 INFO] Loading train dataset from ../bert_data/cnndm.train.11.bert.pt, number of examples: 1999
# [2026-05-11 15:13:19,658 INFO] Step 1850/ 2000; xent: 2.85; lr: 0.0000465;  17 docs/s;   4886 sec
# [2026-05-11 15:15:30,407 INFO] Step 1900/ 2000; xent: 2.86; lr: 0.0000459;  17 docs/s;   5016 sec
# [2026-05-11 15:16:05,715 INFO] Loading train dataset from ../bert_data/cnndm.train.18.bert.pt, number of examples: 1998
# [2026-05-11 15:17:41,071 INFO] Step 1950/ 2000; xent: 2.79; lr: 0.0000453;  17 docs/s;   5147 sec
# [2026-05-11 15:19:51,670 INFO] Step 2000/ 2000; xent: 2.81; lr: 0.0000447;  17 docs/s;   5278 sec
# [2026-05-11 15:19:51,673 INFO] Saving checkpoint ../models/bert_classifier/model_step_2000.pt
# [2026-05-11 15:20:18,816 INFO] Loading train dataset from ../bert_data/cnndm.train.16.bert.pt, number of examples: 2001

# %% [markdown]
# ## 4. Model Evaluation
#
# * `-mode` can be {validate, test}, where validate will inspect the model directory and evaluate the model for each newly saved checkpoint, test need to be used with `-test_from`, indicating the checkpoint you want to use.
# * `-model_path` is the directory of saved checkpoints.
# * use `-mode` valiadte with `-test_all`, the system will load all saved checkpoints and select the top ones to generate summaries (this will take a while)

# %%
# %%shell
# sed -i "s/torch.load(test_from, map_location=lambda storage, loc: storage)/torch.load(test_from, map_location=lambda storage, loc: storage, weights_only=False)/g" train.py

# %%
# !python train.py -mode validate \
          -bert_data_path ../bert_data/cnndm \
          -model_path ../models/bert_classifier  \
          -visible_gpus 0  -gpu_ranks 0 \
          -batch_size 10000  \
          -log_file ../models/bert_classifier/log  \
          -result_path ../models/bert_classifier/results \
          -test_all -block_trigram true
# Out:
# [2026-05-11 15:28:49,146 INFO] Loading checkpoint from ../models/bert_classifier/model_step_500.pt
# Namespace(encoder='classifier', mode='validate', bert_data_path='../bert_data/cnndm', model_path='../models/bert_classifier', result_path='../models/bert_classifier/results', temp_dir='../temp', bert_config_path='../bert_config_uncased_base.json', batch_size=10000, use_interval=True, hidden_size=128, ff_size=512, heads=4, inter_layers=2, rnn_size=512, param_init=0, param_init_glorot=True, dropout=0.1, optim='adam', lr=1, beta1=0.9, beta2=0.999, decay_method='', warmup_steps=8000, max_grad_norm=0, save_checkpoint_steps=5, accum_count=1, world_size=1, report_every=1, train_steps=1000, recall_eval=False, visible_gpus='0', gpu_ranks=[0], log_file='../models/bert_classifier/log', dataset='', seed=666, test_all=True, test_from='', train_from='', report_rouge=True, block_trigram=True)
# [2026-05-11 15:28:57,246 INFO] Loading valid dataset from ../bert_data/cnndm.valid.0.bert.pt, number of examples: 2001
# gpu_rank 0
# [2026-05-11 15:28:57,249 INFO] * number of parameters: 109483009
# [2026-05-11 15:30:16,148 INFO] Loading valid dataset from ../bert_data/cnndm.valid.1.bert.pt, number of examples: 2001
# [2026-05-11 15:31:41,154 INFO] Loading valid dataset from ../bert_data/cnndm.valid.2.bert.pt, number of examples: 2001
# [2026-05-11 15:33:06,099 INFO] Loading valid dataset from ../bert_data/cnndm.valid.3.bert.pt, number of examples: 2000
# [2026-05-11 15:34:31,497 INFO] Loading valid dataset from ../bert_data/cnndm.valid.4.bert.pt, number of examples: 2001
# [2026-05-11 15:35:56,080 INFO] Loading valid dataset from ../bert_data/cnndm.valid.5.bert.pt, number of examples: 2001
# [2026-05-11 15:37:20,074 INFO] Loading valid dataset from ../bert_data/cnndm.valid.6.bert.pt, number of examples: 1362
# [2026-05-11 15:38:16,481 INFO] Validation xent: 5.9865 at step 500
# [2026-05-11 15:38:16,558 INFO] Loading checkpoint from ../models/bert_classifier/model_step_1000.pt
# Namespace(encoder='classifier', mode='validate', bert_data_path='../bert_data/cnndm', model_path='../models/bert_classifier', result_path='../models/bert_classifier/results', temp_dir='../temp', bert_config_path='../bert_config_uncased_base.json', batch_size=10000, use_interval=True, hidden_size=128, ff_size=512, heads=4, inter_layers=2, rnn_size=512, param_init=0, param_init_glorot=True, dropout=0.1, optim='adam', lr=1, beta1=0.9, beta2=0.999, decay_method='', warmup_steps=8000, max_grad_norm=0, save_checkpoint_steps=5, accum_count=1, world_size=1, report_every=1, train_steps=1000, recall_eval=False, visible_gpus='0', gpu_ranks=[0], log_file='../models/bert_classifier/log', dataset='', seed=666, test_all=True, test_from='', train_from='', report_rouge=True, block_trigram=True)
# [2026-05-11 15:38:25,659 INFO] Loading valid dataset from ../bert_data/cnndm.valid.0.bert.pt, number of examples: 2001
# gpu_rank 0
# [2026-05-11 15:38:25,661 INFO] * number of parameters: 109483009
# [2026-05-11 15:39:51,409 INFO] Loading valid dataset from ../bert_data/cnndm.valid.1.bert.pt, number of examples: 2001
# [2026-05-11 15:41:16,670 INFO] Loading valid dataset from ../bert_data/cnndm.valid.2.bert.pt, number of examples: 2001
# [2026-05-11 15:42:41,442 INFO] Loading valid dataset from ../bert_data/cnndm.valid.3.bert.pt, number of examples: 2000
# [2026-05-11 15:44:06,787 INFO] Loading valid dataset from ../bert_data/cnndm.valid.4.bert.pt, number of examples: 2001
# [2026-05-11 15:45:31,341 INFO] Loading valid dataset from ../bert_data/cnndm.valid.5.bert.pt, number of examples: 2001
# [2026-05-11 15:46:55,484 INFO] Loading valid dataset from ../bert_data/cnndm.valid.6.bert.pt, number of examples: 1362
# [2026-05-11 15:47:51,762 INFO] Validation xent: 5.84042 at step 1000
# [2026-05-11 15:47:51,790 INFO] Loading checkpoint from ../models/bert_classifier/model_step_1500.pt
# Namespace(encoder='classifier', mode='validate', bert_data_path='../bert_data/cnndm', model_path='../models/bert_classifier', result_path='../models/bert_classifier/results', temp_dir='../temp', bert_config_path='../bert_config_uncased_base.json', batch_size=10000, use_interval=True, hidden_size=128, ff_size=512, heads=4, inter_layers=2, rnn_size=512, param_init=0, param_init_glorot=True, dropout=0.1, optim='adam', lr=1, beta1=0.9, beta2=0.999, decay_method='', warmup_steps=8000, max_grad_norm=0, save_checkpoint_steps=5, accum_count=1, world_size=1, report_every=1, train_steps=1000, recall_eval=False, visible_gpus='0', gpu_ranks=[0], log_file='../models/bert_classifier/log', dataset='', seed=666, test_all=True, test_from='', train_from='', report_rouge=True, block_trigram=True)
# [2026-05-11 15:48:00,669 INFO] Loading valid dataset from ../bert_data/cnndm.valid.0.bert.pt, number of examples: 2001
# gpu_rank 0
# [2026-05-11 15:48:00,675 INFO] * number of parameters: 109483009
# [2026-05-11 15:49:26,072 INFO] Loading valid dataset from ../bert_data/cnndm.valid.1.bert.pt, number of examples: 2001
# [2026-05-11 15:50:51,029 INFO] Loading valid dataset from ../bert_data/cnndm.valid.2.bert.pt, number of examples: 2001
# [2026-05-11 15:52:15,656 INFO] Loading valid dataset from ../bert_data/cnndm.valid.3.bert.pt, number of examples: 2000
# [2026-05-11 15:53:40,785 INFO] Loading valid dataset from ../bert_data/cnndm.valid.4.bert.pt, number of examples: 2001
# [2026-05-11 15:55:05,223 INFO] Loading valid dataset from ../bert_data/cnndm.valid.5.bert.pt, number of examples: 2001
# [2026-05-11 15:56:29,249 INFO] Loading valid dataset from ../bert_data/cnndm.valid.6.bert.pt, number of examples: 1362
# [2026-05-11 15:57:25,360 INFO] Validation xent: 5.64144 at step 1500
# [2026-05-11 15:57:25,387 INFO] Loading checkpoint from ../models/bert_classifier/model_step_2000.pt
# Namespace(encoder='classifier', mode='validate', bert_data_path='../bert_data/cnndm', model_path='../models/bert_classifier', result_path='../models/bert_classifier/results', temp_dir='../temp', bert_config_path='../bert_config_uncased_base.json', batch_size=10000, use_interval=True, hidden_size=128, ff_size=512, heads=4, inter_layers=2, rnn_size=512, param_init=0, param_init_glorot=True, dropout=0.1, optim='adam', lr=1, beta1=0.9, beta2=0.999, decay_method='', warmup_steps=8000, max_grad_norm=0, save_checkpoint_steps=5, accum_count=1, world_size=1, report_every=1, train_steps=1000, recall_eval=False, visible_gpus='0', gpu_ranks=[0], log_file='../models/bert_classifier/log', dataset='', seed=666, test_all=True, test_from='', train_from='', report_rouge=True, block_trigram=True)
# [2026-05-11 15:57:34,468 INFO] Loading valid dataset from ../bert_data/cnndm.valid.0.bert.pt, number of examples: 2001
# gpu_rank 0
# [2026-05-11 15:57:34,470 INFO] * number of parameters: 109483009
# [2026-05-11 15:58:59,974 INFO] Loading valid dataset from ../bert_data/cnndm.valid.1.bert.pt, number of examples: 2001
# [2026-05-11 16:00:24,989 INFO] Loading valid dataset from ../bert_data/cnndm.valid.2.bert.pt, number of examples: 2001
# [2026-05-11 16:01:49,786 INFO] Loading valid dataset from ../bert_data/cnndm.valid.3.bert.pt, number of examples: 2000
# [2026-05-11 16:03:14,814 INFO] Loading valid dataset from ../bert_data/cnndm.valid.4.bert.pt, number of examples: 2001
# [2026-05-11 16:04:39,554 INFO] Loading valid dataset from ../bert_data/cnndm.valid.5.bert.pt, number of examples: 2001
# [2026-05-11 16:06:03,909 INFO] Loading valid dataset from ../bert_data/cnndm.valid.6.bert.pt, number of examples: 1362
# [2026-05-11 16:07:00,037 INFO] Validation xent: 5.6249 at step 2000
# [2026-05-11 16:07:00,056 INFO] PPL [(5.624896503613152, '../models/bert_classifier/model_step_2000.pt'), (5.641443938050335, '../models/bert_classifier/model_step_1500.pt'), (5.840418371808568, '../models/bert_classifier/model_step_1000.pt')]
# [2026-05-11 16:07:00,056 INFO] Loading checkpoint from ../models/bert_classifier/model_step_2000.pt
# Namespace(encoder='classifier', mode='validate', bert_data_path='../bert_data/cnndm', model_path='../models/bert_classifier', result_path='../models/bert_classifier/results', temp_dir='../temp', bert_config_path='../bert_config_uncased_base.json', batch_size=10000, use_interval=True, hidden_size=128, ff_size=512, heads=4, inter_layers=2, rnn_size=512, param_init=0, param_init_glorot=True, dropout=0.1, optim='adam', lr=1, beta1=0.9, beta2=0.999, decay_method='', warmup_steps=8000, max_grad_norm=0, save_checkpoint_steps=5, accum_count=1, world_size=1, report_every=1, train_steps=1000, recall_eval=False, visible_gpus='0', gpu_ranks=[0], log_file='../models/bert_classifier/log', dataset='', seed=666, test_all=True, test_from='', train_from='', report_rouge=True, block_trigram=True)
# [2026-05-11 16:07:05,450 INFO] Loading test dataset from ../bert_data/cnndm.test.0.bert.pt, number of examples: 2001
# gpu_rank 0
# [2026-05-11 16:07:05,453 INFO] * number of parameters: 109483009
# [2026-05-11 16:08:31,043 INFO] Loading test dataset from ../bert_data/cnndm.test.1.bert.pt, number of examples: 2001
# [2026-05-11 16:09:57,014 INFO] Loading test dataset from ../bert_data/cnndm.test.2.bert.pt, number of examples: 2001
# [2026-05-11 16:11:22,770 INFO] Loading test dataset from ../bert_data/cnndm.test.3.bert.pt, number of examples: 2001
# [2026-05-11 16:12:47,803 INFO] Loading test dataset from ../bert_data/cnndm.test.4.bert.pt, number of examples: 2000
# [2026-05-11 16:14:11,876 INFO] Loading test dataset from ../bert_data/cnndm.test.5.bert.pt, number of examples: 1485
# 11489
# 11489
# 2026-05-11 16:15:13,782 [MainThread  ] [INFO ]  Writing summaries.
# [2026-05-11 16:15:13,782 INFO] Writing summaries.
# 2026-05-11 16:15:13,783 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /content/BertSum/temp/tmpenuwtoex/system and model files to /content/BertSum/temp/tmpenuwtoex/model.
# [2026-05-11 16:15:13,783 INFO] Processing summaries. Saving system files to /content/BertSum/temp/tmpenuwtoex/system and model files to /content/BertSum/temp/tmpenuwtoex/model.
# 2026-05-11 16:15:13,783 [MainThread  ] [INFO ]  Processing files in ../temp/rouge-tmp-2026-05-11-16-15-12/candidate/.
# [2026-05-11 16:15:13,783 INFO] Processing files in ../temp/rouge-tmp-2026-05-11-16-15-12/candidate/.
# 2026-05-11 16:15:14,891 [MainThread  ] [INFO ]  Saved processed files to /content/BertSum/temp/tmpenuwtoex/system.
# [2026-05-11 16:15:14,891 INFO] Saved processed files to /content/BertSum/temp/tmpenuwtoex/system.
# 2026-05-11 16:15:14,892 [MainThread  ] [INFO ]  Processing files in ../temp/rouge-tmp-2026-05-11-16-15-12/reference/.
# [2026-05-11 16:15:14,892 INFO] Processing files in ../temp/rouge-tmp-2026-05-11-16-15-12/reference/.
# 2026-05-11 16:15:15,762 [MainThread  ] [INFO ]  Saved processed files to /content/BertSum/temp/tmpenuwtoex/model.
# [2026-05-11 16:15:15,762 INFO] Saved processed files to /content/BertSum/temp/tmpenuwtoex/model.
# 2026-05-11 16:15:15,849 [MainThread  ] [INFO ]  Written ROUGE configuration to /content/BertSum/temp/tmpszktb70d/rouge_conf.xml
# [2026-05-11 16:15:15,849 INFO] Written ROUGE configuration to /content/BertSum/temp/tmpszktb70d/rouge_conf.xml
# 2026-05-11 16:15:15,849 [MainThread  ] [INFO ]  Running ROUGE with command /content/pyrouge/tools/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /content/pyrouge/tools/ROUGE-1.5.5/data -c 95 -m -r 1000 -n 2 -a /content/BertSum/temp/tmpszktb70d/rouge_conf.xml
# [2026-05-11 16:15:15,849 INFO] Running ROUGE with command /content/pyrouge/tools/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /content/pyrouge/tools/ROUGE-1.5.5/data -c 95 -m -r 1000 -n 2 -a /content/BertSum/temp/tmpszktb70d/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.54024 (95%-conf.int. 0.53765 - 0.54292)
# 1 ROUGE-1 Average_P: 0.36962 (95%-conf.int. 0.36729 - 0.37190)
# 1 ROUGE-1 Average_F: 0.42460 (95%-conf.int. 0.42247 - 0.42673)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.24766 (95%-conf.int. 0.24492 - 0.25016)
# 1 ROUGE-2 Average_P: 0.16962 (95%-conf.int. 0.16752 - 0.17171)
# 1 ROUGE-2 Average_F: 0.19450 (95%-conf.int. 0.19231 - 0.19658)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.49304 (95%-conf.int. 0.49038 - 0.49565)
# 1 ROUGE-L Average_P: 0.33793 (95%-conf.int. 0.33574 - 0.34015)
# 1 ROUGE-L Average_F: 0.38792 (95%-conf.int. 0.38580 - 0.39000)
#
# [2026-05-11 16:17:16,940 INFO] Rouges at step 2000
# >> ROUGE-F(1/2/3/l): 42.46/19.45/38.79
# ROUGE-R(1/2/3/l): 54.02/24.77/49.30
#
# [2026-05-11 16:17:16,940 INFO] Validation xent: 5.57908 at step 2000
# [2026-05-11 16:17:16,960 INFO] Loading checkpoint from ../models/bert_classifier/model_step_1500.pt
# Namespace(encoder='classifier', mode='validate', bert_data_path='../bert_data/cnndm', model_path='../models/bert_classifier', result_path='../models/bert_classifier/results', temp_dir='../temp', bert_config_path='../bert_config_uncased_base.json', batch_size=10000, use_interval=True, hidden_size=128, ff_size=512, heads=4, inter_layers=2, rnn_size=512, param_init=0, param_init_glorot=True, dropout=0.1, optim='adam', lr=1, beta1=0.9, beta2=0.999, decay_method='', warmup_steps=8000, max_grad_norm=0, save_checkpoint_steps=5, accum_count=1, world_size=1, report_every=1, train_steps=1000, recall_eval=False, visible_gpus='0', gpu_ranks=[0], log_file='../models/bert_classifier/log', dataset='', seed=666, test_all=True, test_from='', train_from='', report_rouge=True, block_trigram=True)
# [2026-05-11 16:17:21,389 INFO] Loading test dataset from ../bert_data/cnndm.test.0.bert.pt, number of examples: 2001
# gpu_rank 0
# [2026-05-11 16:17:21,393 INFO] * number of parameters: 109483009
# [2026-05-11 16:18:47,061 INFO] Loading test dataset from ../bert_data/cnndm.test.1.bert.pt, number of examples: 2001
# [2026-05-11 16:20:12,454 INFO] Loading test dataset from ../bert_data/cnndm.test.2.bert.pt, number of examples: 2001
# [2026-05-11 16:21:37,522 INFO] Loading test dataset from ../bert_data/cnndm.test.3.bert.pt, number of examples: 2001
# [2026-05-11 16:23:02,613 INFO] Loading test dataset from ../bert_data/cnndm.test.4.bert.pt, number of examples: 2000
# [2026-05-11 16:24:26,571 INFO] Loading test dataset from ../bert_data/cnndm.test.5.bert.pt, number of examples: 1485
# 11489
# 11489
# 2026-05-11 16:25:28,468 [MainThread  ] [INFO ]  Writing summaries.
# [2026-05-11 16:25:28,468 INFO] Writing summaries.
# 2026-05-11 16:25:28,469 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /content/BertSum/temp/tmpjrxy5qod/system and model files to /content/BertSum/temp/tmpjrxy5qod/model.
# [2026-05-11 16:25:28,469 INFO] Processing summaries. Saving system files to /content/BertSum/temp/tmpjrxy5qod/system and model files to /content/BertSum/temp/tmpjrxy5qod/model.
# 2026-05-11 16:25:28,469 [MainThread  ] [INFO ]  Processing files in ../temp/rouge-tmp-2026-05-11-16-25-27/candidate/.
# [2026-05-11 16:25:28,469 INFO] Processing files in ../temp/rouge-tmp-2026-05-11-16-25-27/candidate/.
# 2026-05-11 16:25:29,546 [MainThread  ] [INFO ]  Saved processed files to /content/BertSum/temp/tmpjrxy5qod/system.
# [2026-05-11 16:25:29,546 INFO] Saved processed files to /content/BertSum/temp/tmpjrxy5qod/system.
# 2026-05-11 16:25:29,546 [MainThread  ] [INFO ]  Processing files in ../temp/rouge-tmp-2026-05-11-16-25-27/reference/.
# [2026-05-11 16:25:29,546 INFO] Processing files in ../temp/rouge-tmp-2026-05-11-16-25-27/reference/.
# 2026-05-11 16:25:30,510 [MainThread  ] [INFO ]  Saved processed files to /content/BertSum/temp/tmpjrxy5qod/model.
# [2026-05-11 16:25:30,510 INFO] Saved processed files to /content/BertSum/temp/tmpjrxy5qod/model.
# 2026-05-11 16:25:30,605 [MainThread  ] [INFO ]  Written ROUGE configuration to /content/BertSum/temp/tmpx_mj26v3/rouge_conf.xml
# [2026-05-11 16:25:30,605 INFO] Written ROUGE configuration to /content/BertSum/temp/tmpx_mj26v3/rouge_conf.xml
# 2026-05-11 16:25:30,605 [MainThread  ] [INFO ]  Running ROUGE with command /content/pyrouge/tools/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /content/pyrouge/tools/ROUGE-1.5.5/data -c 95 -m -r 1000 -n 2 -a /content/BertSum/temp/tmpx_mj26v3/rouge_conf.xml
# [2026-05-11 16:25:30,605 INFO] Running ROUGE with command /content/pyrouge/tools/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /content/pyrouge/tools/ROUGE-1.5.5/data -c 95 -m -r 1000 -n 2 -a /content/BertSum/temp/tmpx_mj26v3/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.53097 (95%-conf.int. 0.52812 - 0.53348)
# 1 ROUGE-1 Average_P: 0.37230 (95%-conf.int. 0.36990 - 0.37463)
# 1 ROUGE-1 Average_F: 0.42315 (95%-conf.int. 0.42102 - 0.42525)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.24275 (95%-conf.int. 0.23993 - 0.24539)
# 1 ROUGE-2 Average_P: 0.17059 (95%-conf.int. 0.16863 - 0.17256)
# 1 ROUGE-2 Average_F: 0.19344 (95%-conf.int. 0.19134 - 0.19544)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.48511 (95%-conf.int. 0.48244 - 0.48763)
# 1 ROUGE-L Average_P: 0.34080 (95%-conf.int. 0.33851 - 0.34304)
# 1 ROUGE-L Average_F: 0.38704 (95%-conf.int. 0.38492 - 0.38911)
#
# [2026-05-11 16:27:26,607 INFO] Rouges at step 1500
# >> ROUGE-F(1/2/3/l): 42.32/19.34/38.70
# ROUGE-R(1/2/3/l): 53.10/24.27/48.51
#
# [2026-05-11 16:27:26,607 INFO] Validation xent: 5.60172 at step 1500
# [2026-05-11 16:27:26,679 INFO] Loading checkpoint from ../models/bert_classifier/model_step_1000.pt
# Namespace(encoder='classifier', mode='validate', bert_data_path='../bert_data/cnndm', model_path='../models/bert_classifier', result_path='../models/bert_classifier/results', temp_dir='../temp', bert_config_path='../bert_config_uncased_base.json', batch_size=10000, use_interval=True, hidden_size=128, ff_size=512, heads=4, inter_layers=2, rnn_size=512, param_init=0, param_init_glorot=True, dropout=0.1, optim='adam', lr=1, beta1=0.9, beta2=0.999, decay_method='', warmup_steps=8000, max_grad_norm=0, save_checkpoint_steps=5, accum_count=1, world_size=1, report_every=1, train_steps=1000, recall_eval=False, visible_gpus='0', gpu_ranks=[0], log_file='../models/bert_classifier/log', dataset='', seed=666, test_all=True, test_from='', train_from='', report_rouge=True, block_trigram=True)
# [2026-05-11 16:27:35,379 INFO] Loading test dataset from ../bert_data/cnndm.test.0.bert.pt, number of examples: 2001
# gpu_rank 0
# [2026-05-11 16:27:35,381 INFO] * number of parameters: 109483009
# [2026-05-11 16:29:00,087 INFO] Loading test dataset from ../bert_data/cnndm.test.1.bert.pt, number of examples: 2001
# [2026-05-11 16:30:25,111 INFO] Loading test dataset from ../bert_data/cnndm.test.2.bert.pt, number of examples: 2001
# [2026-05-11 16:31:50,489 INFO] Loading test dataset from ../bert_data/cnndm.test.3.bert.pt, number of examples: 2001
# [2026-05-11 16:33:16,297 INFO] Loading test dataset from ../bert_data/cnndm.test.4.bert.pt, number of examples: 2000
# [2026-05-11 16:34:41,395 INFO] Loading test dataset from ../bert_data/cnndm.test.5.bert.pt, number of examples: 1485
# 11489
# 11489
# 2026-05-11 16:35:43,713 [MainThread  ] [INFO ]  Writing summaries.
# [2026-05-11 16:35:43,713 INFO] Writing summaries.
# 2026-05-11 16:35:43,715 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /content/BertSum/temp/tmprvgzpyom/system and model files to /content/BertSum/temp/tmprvgzpyom/model.
# [2026-05-11 16:35:43,715 INFO] Processing summaries. Saving system files to /content/BertSum/temp/tmprvgzpyom/system and model files to /content/BertSum/temp/tmprvgzpyom/model.
# 2026-05-11 16:35:43,715 [MainThread  ] [INFO ]  Processing files in ../temp/rouge-tmp-2026-05-11-16-35-42/candidate/.
# [2026-05-11 16:35:43,715 INFO] Processing files in ../temp/rouge-tmp-2026-05-11-16-35-42/candidate/.
# 2026-05-11 16:35:44,756 [MainThread  ] [INFO ]  Saved processed files to /content/BertSum/temp/tmprvgzpyom/system.
# [2026-05-11 16:35:44,756 INFO] Saved processed files to /content/BertSum/temp/tmprvgzpyom/system.
# 2026-05-11 16:35:44,756 [MainThread  ] [INFO ]  Processing files in ../temp/rouge-tmp-2026-05-11-16-35-42/reference/.
# [2026-05-11 16:35:44,756 INFO] Processing files in ../temp/rouge-tmp-2026-05-11-16-35-42/reference/.
# 2026-05-11 16:35:45,678 [MainThread  ] [INFO ]  Saved processed files to /content/BertSum/temp/tmprvgzpyom/model.
# [2026-05-11 16:35:45,678 INFO] Saved processed files to /content/BertSum/temp/tmprvgzpyom/model.
# 2026-05-11 16:35:45,739 [MainThread  ] [INFO ]  Written ROUGE configuration to /content/BertSum/temp/tmp60tej6s6/rouge_conf.xml
# [2026-05-11 16:35:45,739 INFO] Written ROUGE configuration to /content/BertSum/temp/tmp60tej6s6/rouge_conf.xml
# 2026-05-11 16:35:45,739 [MainThread  ] [INFO ]  Running ROUGE with command /content/pyrouge/tools/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /content/pyrouge/tools/ROUGE-1.5.5/data -c 95 -m -r 1000 -n 2 -a /content/BertSum/temp/tmp60tej6s6/rouge_conf.xml
# [2026-05-11 16:35:45,739 INFO] Running ROUGE with command /content/pyrouge/tools/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /content/pyrouge/tools/ROUGE-1.5.5/data -c 95 -m -r 1000 -n 2 -a /content/BertSum/temp/tmp60tej6s6/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.53510 (95%-conf.int. 0.53221 - 0.53778)
# 1 ROUGE-1 Average_P: 0.36439 (95%-conf.int. 0.36196 - 0.36666)
# 1 ROUGE-1 Average_F: 0.41933 (95%-conf.int. 0.41709 - 0.42149)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.24339 (95%-conf.int. 0.24054 - 0.24605)
# 1 ROUGE-2 Average_P: 0.16603 (95%-conf.int. 0.16379 - 0.16800)
# 1 ROUGE-2 Average_F: 0.19062 (95%-conf.int. 0.18829 - 0.19267)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.48833 (95%-conf.int. 0.48542 - 0.49090)
# 1 ROUGE-L Average_P: 0.33306 (95%-conf.int. 0.33063 - 0.33527)
# 1 ROUGE-L Average_F: 0.38302 (95%-conf.int. 0.38073 - 0.38506)
#
# [2026-05-11 16:37:45,664 INFO] Rouges at step 1000
# >> ROUGE-F(1/2/3/l): 41.93/19.06/38.30
# ROUGE-R(1/2/3/l): 53.51/24.34/48.83
#
# [2026-05-11 16:37:45,664 INFO] Validation xent: 5.802 at step 1000
